# %%
# 라이브러리 import
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# 구글 검색창에 입력한 my users agent 정보를 headers에 설정
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Whale/3.22.205.26 Safari/537.36'}

# 크롤링할 페이지가 있는 주소값을 넣기
url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r = requests.get(url, headers=headers)
r.status_code
# Out:
# 200

# %%
# 분석할 html 소스 가져오기
soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"gdpr":{"consentLanguage":"en"},"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport"/>
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" property="og:url"/>
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.transfermarkt.ch/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="world" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.ro/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ro" rel="alternate"/>
# <link href="https://www.transfermarkt.gr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="el-GR" rel="alternate"/>
# <link href="https://www.transfermarkt.co.kr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ko-KR" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.pe/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.my/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1698743558" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1698743576" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1698743566" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1698743566" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1698743566" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1698743565" type="text/javascript"></script>
# <title>Most valuable players | Transfermarkt</title>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/manager/base/es6/bundle.js" id="IOMmBundle" rel="preload"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" rel="preload"/>
# <script src="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" type="text/javascript"></script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#     </script>
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 01111813 */ !function(t,e){function n(t,e){var n=Ut(t);if(!n)return n;if(""!=e)for(var i=0;i<e.length;i++){var r=f(e,i);"^"==r&&(n=n.parentNode),"<"==r&&(n=n.previousElementSibling),">"==r&&(n=n.nextElementSibling),"y"==r&&(n=n.firstChild)}return n}function i(t,e){var n=at(e);return{x:t.clientX-n.left,y:t.clientY-n.top}}function r(t){for(var e=0,n=0;t;)e+=t.offsetLeft+t.clientLeft,n+=t.offsetTop+t.clientTop,t=t.offsetParent;return{x:e,y:n}}function d(t,e){var n=0,i=0,d=r(e);return(t.pageX||t.pageY)&&(n=t.pageX,i=t.pageY),(t.clientX||t.clientY)&&(n=t.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,i=t.clientY+document.body.scrollTop+document.documentElement.scrollTop),n-=d.x,i-=d.y,{x:n,y:i}}function o(t,e){return ft(e)?i(t,e):d(t,e)}function l(t,e){t.addEventListener?U(t,"click",e,!0):t.attachEvent&&t.attachEvent("onclick",function(){return e.call(t,window.event)})}function h(e,n){return t[R("c2V0VGltZW91dA==")](e,n)}function p(t){return parseInt(t.toString().split(".")[0],10)}function f(t,e){return t[e]}function a(){return At=(Bt*At+Dt)%Jt}function u(){return a()/(Jt-1)}function s(){return u()}function z(t,e){return t>e?t:e}function c(){for(var t="",e=65;e<91;e++)t+=m(e);for(var e=97;e<123;e++)t+=m(e);return t}function m(t){return f(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+f("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",t-32)}function R(t){var e,n,i,r,d,o,l,h=c()+"0123456789+/=",p="",a=0;for(t=t.replace(/[^A-Za-z0-9\+\/\=]/g,"");a<t.length;)r=h.indexOf(f(t,a++)),d=h.indexOf(f(t,a++)),o=h.indexOf(f(t,a++)),l=h.indexOf(f(t,a++)),e=r<<2|d>>4,n=(15&d)<<4|o>>2,i=(3&o)<<6|l,p+=m(e),64!=o&&(p+=m(n)),64!=l&&(p+=m(i));return p}function y(t){for(var e=c()+"0123456789+/=",n=t.length-1,i=-1,r="";i<n;){var d=t.charCodeAt(++i)<<16|t.charCodeAt(++i)<<8|t.charCodeAt(++i);r+=e[d>>>18&63]+e[d>>>12&63]+e[d>>>6&63]+e[63&d]}var o=t.length%3;if(o>0)for(r=r.slice(0,o-3);r.length%4!=0;)r+="=";return r}function x(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(t){return"unknown"}}function U(e,n,i,r){r=r||!1;try{e.addEventListener(n,i,r),t.mtyhzClne.push([e,n,i,r])}catch(d){e.attachEvent&&(e.attachEvent("on"+n,i),t.mtyhzClne.push([e,n,i,r]))}}function b(t){if(!t)return"";for(var e=R("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),n="",i=0;i<t.length;i++){n+=e.indexOf(t[i])>-1?R("XA==")+t[i]:t[i]}return n}function v(t){if(!t)return"";var e="";return t.id&&t.id.length>0&&(e+="#"+b(t.id)),t.className&&t.className.length>0&&(e+="."+b(t.className).split(" ").filter(function(t){return t&&t.length>0}).join(".")),e}function V(t){_t[t]=!1}function g(e,n){var i=Ct++;t.mtyhzClni&&t.mtyhzClni.push(i),_t[i]=!0;var r=function(t){return function(){e.call(null),_t[i]&&h(r,t)}}(n);return h(r,n),i}function w(t){var e=!1;return Object.keys(t).forEach(function(n){e=e||t[n]}),!e}function T(t,e){return t&&(t.consents&&t.consents[e]||t.legitimateInterests&&t.legitimateInterests[e])}function F(e){return!!t.mtyhz277Flags.strictNCNA&&(T(e,2)&&T(e,7)&&T(e,9)&&T(e,10))}function E(e){return t[R("ZW5jb2RlVVJJQ29tcG9uZW50")](e)}function N(t,e,n){var i=function(){return!!e()&&(n(),!0)};if(!i()){var r=g(function(){i()&&V(r)},250);i()}}function W(t){j(t)}function j(t){if(t.mtyhz969sdl&&!t.mtyhz077Injct){t.mtyhz077Injct=!0,t.mtyhz838Pc={},t.mtyhz1f6Oc=[],t.mtyhz0cfAm={},t.mtyhzf6dAv={},t.mtyhz8b9Aw={},t.mtyhz7d9Rqr={},t.mtyhzfd0Rqq=[],t.mtyhzf6dAvt={},t.mtyhz242Ev={};var n=[];if(!t.mtyhz277Flags.welect.eenabled||NLBYAWelect()){if(mtyhz277Flags.ptcb1ls){var i=mtyhz277Flags.ba267it,r=mtyhz277Flags.mb128el||10,d=mtyhz277Flags.ig647BP,o=function(){var t=it("style");t.type="text/css";var n=!1,i=it("style");i.type="text/css";var r=!1;return function(o,l){if(l)if("b"!==o||n){if("r"===o)if(r){var h=i,p=h.sheet;p.insertRule(l,0)}else r=!0,rt(i,l),dt(e.body,i)}else{if(n=!0,d)for(var f=0;f<d.length;f++)l=l.replace(new RegExp("([;{])"+d[f]+": [^;]+;","g"),"$1");var h="[^:;{",p="!important;";l=l.replace(new RegExp(h+"}]+: [^;]+\\s"+ ...
# ;rt(d,""+R(Xt(R("..."),-3))),wt(d.childNodes,function(e,i){zt(n,i),t.mtyhzCln.push(i)}),t.mtyhzCln.push(n)}function z(e){var n=it("div");r[""+R(Xt(R("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94WzRRdmU2VX0="),-3))]=n,r[""+R(Xt(R("UkdufVJEQEA="),-3))]=n,i[""+R(Xt(R("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94WzRRdmU2VX0="),-3))]=n,zt(e,n),t.mtyhzd10a4.w[8938]=n;var d=it("div");rt(d,""+R(Xt(R("..."),-3))),wt(d.childNodes,function(e,i){zt(n,i),t.mtyhzCln.push(i)}),M([{function:function(t,e){t.remove&&t.remove()}}],n,8938),t.mtyhzCln.push(n)}function c(e){var n=it("div");r[""+R(Xt(R("WTVJdmVLRWtmSll8WzRnVlRZRVRVWUxA"),-3))]=n,r[""+R(Xt(R("UkdcOFF6QEA="),-3))]=n,i[""+R(Xt(R("WTVJdmVLRWtmSll8WzRnVlRZRVRVWUxA"),-3))]=n,xt(n,"RNkhlrGmU"),yt(n,"xPyuYr "),zt(e,n),t.mtyhzd10a4.w[8697]=n,t.mtyhzCln.push(n)}function m(e){if(t.mtyhzfc1Mobile&&(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1)){var n=r[""+R(Xt(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbfUhA"),-3))];n&&e(n)}}function y(e){var n=it("div");r[""+R(Xt(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0O3s="),-3))]=n,r[""+R(Xt(R("UFdQN1JHSEA="),-3))]=n,i[""+R(Xt(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0O3s="),-3))]=n,yt(n,"hIoMCee "),dt(e,n),t.mtyhzd10a4.w[13881]=n;var d=it("div");rt(d,""+R(Xt(R("U0pVc2dsRXNdRzNsZjVdeVxtSGxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1MbFNsRDtPNVVzZ203alNKVXNnbEVzXUczbGY1XXlcbVBsU2xEO081VXNnbTdqU0pVc2dsRXNdRzNsZjVdeVxtVGxTbEQ7TzVVc2dtN0A="),-3))),wt(d.childNodes,function(e,i){zt(n,i),t.mtyhzCln.push(i)}),t.mtyhzCln.push(n)}function x(e){if(t.mtyhzd10atc.pm&&t.mtyhzfc1Mobile&&(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1)){var n=r[""+R(Xt(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbNEVR"),-3))];n&&e(n)}}function U(e){var n=it("div");r[""+R(Xt(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0PFRXVEBA"),-3))]=n,r[""+R(Xt(R("UFdQN1JXUEA="),-3))]=n,i[""+R(Xt(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0PFRXVEBA"),-3))]=n,xt(n,"fPFsVrKtR"),yt(n,"unYnbCXhf "),dt(e,n),t.mtyhzd10a4.w[13893]=n;var d=it("div");rt(d,""+R(Xt(R("U0pVc2dsRXNdRzNsZjVdaWRKemxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1IbFNsRDtPNVVzZ203alNKVXNnbEVzXUczbGY1XXlcbUxsU2xEO081VXNnbTdqU0pVc2dsRXNdRzNsZjVdeVxtUGxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1UbFNsRDtPNVVzZ203QA=="),-3))),wt(d.childNodes,function(e,i){zt(n,i),t.mtyhzCln.push(i)}),t.mtyhzCln.push(n)}N(13884,function(){var t=!0,e=n(""+R(Xt(R("T248WVlITVZUWG9SWjVVa2dKSHdnNW9uXTVZM09ab25TVk1FWG87e0xvM2pPcDxsT1pRa2ZwVX0="),-3)),"");return t=t&&e},function(){d(o)}),N(13892,function(){var t=!0,e=n(""+R(Xt(R("T248WVlITVZUWG9SWjVVa2dKSHdnNW9uXTVZM09ab25TVk1FWG87e0xvM0A="),-3)),"");return t=t&&e},function(){l(h)}),function(e){if(t.mtyhz277Flags.video){var i=n(""+R(Xt(R("TDVreWVaWHdmcFltZ0pJeF01e29PW1F6ZTZVdmRaZ3JnRkR2TEY4Nl1bTWxnWjhxT1tNb1w2VWtlcGd2XVdIQA=="),-3)),"");i&&e(i)}}(p),function(e){if(t.mtyhz277Flags.video){var i=n(""+R(Xt(R("ZVpJc2VsRC5MRjh8ZTZmalNsRHhlSkl8XTVYd1JGRHhlcFk2Znw0NmRaVXFdW1R3T1pReWVxVWtkWjhvZmxEdUxGcnZMSjRrZFo3alNsRHhmcDw2TEc3ak9we2tmcGdvT1dqak9xXXNdW2d6ZTZNM09bVXxcWlF1ZFo4cUxGdmpOakBA"),-3)),"");i&&e(i)}}(f),function(e){if(!(t.mtyhzfc1Mobile||t.mtyhz277Flags.ncna&&t.mtyhzfc1Mobile)){var i=n(""+R(Xt(R("T3Fnb2ZwTTRlcGZ3ZjV3OGY1UXxcW0VvZmw0bWU1ODNcWm94XVtMQA=="),-3)),"");i&&e(i)}}(a),N(13886,function(){var t=!0,e=n(""+R(Xt(R("TDZRcFs1a3Y="),-3)),"");return t=t&&e},function(){u(s)}),function(e){if(!(t.mtyhzfc1Mobile||t.mtyhz277Flags.ncna&&t.mtyhzfc1Mobile)){var i=n(""+R(Xt(R("TDZNb1w1PHdlWll4XUpZfA=="),-3)),"");i&&e(i)}}(z),function(i){if(!t.mtyhzfc1Mobile&&938<=(t.innerWidth||e.documentElement.clientWidth||e.body.clientWidth)&&(!t.mtyhz277Flags.ncna||!t.mtyhzfc1Mobile&&938<=(t.innerWidth||e.documentElement.clientWidth||e.body.clientWidth))){var r=n(""+R(Xt(R("TDU4a2dwb2xcWnt1XVo3dkw1NGtkWjdA"),-3)),"");r&&i(r)}}(c),N(13881,function(){var t=!0,e=r[""+R(Xt(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSX ...
# }function d(t,e){var i=n[""+R(Xt(R("V1lNaVk2TWtmS0VvZmpAQA=="),-3))];i?t(i):e(12352)}function o(i){var r=it("div");n[""+R(Xt(R("VzZZM2Y2VXxdWkl3WzM0Vg=="),-3))]=r,n[""+R(Xt(R("UFdMfVFXTEA="),-3))]=r,e[""+R(Xt(R("VzZZM2Y2VXxdWkl3WzM0Vg=="),-3))]=r;var d;xt(r,"VLFKDWtCXq"),d="#VLFKDWtCXq",dt(i,r),t.mtyhzd10a4.a[12352]=r;var o=[];(t.mtyhzd10atc.gn||t.mtyhzd10atc.ab)&&o.push(R("QURCTE9DSw==")),t.mtyhzd10atc.pm&&o.push("PM"),t.mtyhz277Flags.nc&&o.push("NC"),0===o.length&&o.push("NONE"),t.postMessage({from:ne,to:ie,message:{type:"loadVideoTag",value:{positionId:12352,cssSelector:d,currentTrafficTypes:o}}}),M([{function:function(t,e){g(function(){t.classList.add("nolbl");var e=t.innerText.toLowerCase();e.indexOf("anzeige")>-1||e.indexOf("advertisement")>-1?t.classList.add("nolbl"):at(t).height>=100&&t.classList.remove("nolbl")},500)}}],r,12352),t.mtyhzCln.push(r)}N(12353,function(){var e=!0,i=n[""+R(Xt(R("VzZZM2Y2VXxdWkl3WzNdV1s0Z3xcW0V6XVtMQA=="),-3))];return e=e&&i,e=e&&e.getBoundingClientRect().top-t.innerHeight<=-150},function(){i(r,S)}),N(12352,function(){var e=!0,i=n[""+R(Xt(R("V1lNaVk2TWtmS0VvZmpAQA=="),-3))];return e=e&&i,e=e&&e.getBoundingClientRect().top-t.innerHeight<=-150},function(){d(o,S)})}function q(i,r){function d(e,n,r,d){r||vt(Xt("22zzz1wudqvihupdunw1frp2lpdjh25prurNR\\Zg37VSlKFoxoHphN}rNnEj\\LmpQ4NYh8<Qmf2"+t.mtyhz7b2Rnd+"QKQYL4ei;uJ39S<m|GoGSLYRXqMwe]eeMhyi<YlGYeW:WtH1jli",-3),function(){if(!r){r=!0;var h=this;if(h.height<2)return void S(8694,n,!1);if(d==t.mtyhz7b2Rnd){var f=e,a=it("div");i[""+R(Xt(R("VG5vUFdEQEA="),-3))]=a,yt(a,"WDIZXsmiFx ");var u=h;t.mtyhz0cfAm[8694]&&(Y(t.mtyhz0cfAm[8694]),t.mtyhz0cfAm[8694]=!1),l(u,function(e,n){if(!t.mtyhz838Pc[8694]){e.preventDefault(),e.stopPropagation();for(var n=o(e,this),i=0;i<t.mtyhz1f6Oc.length;i++){var r=t.mtyhz1f6Oc[i];if(8694==r.p&&n.x>=r.x&&n.x<r.x+r.w&&n.y>=r.y&&n.y<r.y+r.h){if(r.u){var d=r.t.length>0?r.t:"_self";d=0==e.button&&e.ctrlKey?"_blank":d,Ft(t,r.u,r.u,d,!0)}return}}var l=[Xt("22zzz1wudqvihupdunw1frp2lpdjh2\\u}YYwYF[jii:eur<4{tOl}OWgRhF4oifEjnU}j78WlT2"+t.mtyhz7b2Rnd+"HLNX4n9VXkO5o[qSq{7IPxex\\UlFj67pY\\NoP{<6X6TJIOv1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2uNVWf|Lxw]kTpZQgfy69XsPNYnx]];EzN5f5nSxh;jON2"+t.mtyhz7b2Rnd+"MZ]IexT[Ozywv:gkQ7uv9pPzzzOLQJ<r<p{jqZ[:QrYHsUW1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2TeLF\\lPFp{mfPE8pQfS:}7FSpeW<5qZtjZe:H\\Xh95su2"+t.mtyhz7b2Rnd+"T]P{V5I3|iO4orNE]Qu|k|;|Gq[x6Uwj6lmiYUmKSo}fmOe1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2Y<lGo:;Qt{HFYT8nVy:\\s:XsxYHxJ\\6T\\ITkF\\lP7;Nt2"+t.mtyhz7b2Rnd+"ZM]ktqMi\\[sV:SQXtIl<{gfuUnYVz645\\[:r]sRimqeJ|3q1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh27}Kr85m5;PT9xU}:fwhhK5Xzg8sYVxOqokWeOwS7F9X;2"+t.mtyhz7b2Rnd+"ZNH}\\un9oymI4iONtgSo\\lxGnXzX<jkKSpOMIVU78[kv8;n1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2P];EqKY|\\u\\Lp<yPSm9<w75uYEJ8FXEkG|zJk:Ej6<S<2"+t.mtyhz7b2Rnd+"M[]\\|{:}zve9jqKOToEQkv{<TG7J]KZ6J;<Qz6VH<RZYWQl1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh27lySJfLus5|tVeL3NRSy}HlKSETgXQ35sxFeZJ4jeNOu2"+t.mtyhz7b2Rnd+"JPJSueK[L|s4RzM[{8XEpiuw69yuIvVNp{toKGXyeo55Q[[1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2IPH<[kFE9E5fqu9T}8}\\kGrk|PhsPV;<:4WzXWhi{UfV2"+t.mtyhz7b2Rnd+"YR[ieMpUy9\\LyMuKVwwZhox7yw<L|XZW\\eRw[hYiFgkyrH[1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2uN3Lu|Skmo5H|TyiGsVMOZ|[;t]r<Zj<PeHHNRtJ5pKp2"+t.mtyhz7b2Rnd+"YJX]9}vrfEgQ}]uQtLom|6lRmiisGy|lE5yrfpyZ5QzOHk71jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2QEfqn}O7]E::IYVo87:3v8|yhINfLVUry:qRY3v6i3G92"+t.mtyhz7b2Rnd+"LN[{5P9OO|SUSz4{inv;qw5sfIZsTYYzRrtEG3keNW\\t\\4s1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2VNNlH[qg7wGMiy8m]quE9IN5j[8|j;Ih4I94NU]4RWy62"+t.mtyhz7b2Rnd+"LH]]te3wuw]6HozGk[XZMurq68M[f5:65uEEXmiinWOJg]e1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2xmIOf5n8gV9tggnrJU}ZS6OtMzo9gFJIX7o6{wUleyIt2"+t.mtyhz7b2Rnd+"URXG;l9sM;Tf|whIsXnE|SJ8:[3|TTnGPHRz83y3k7YP}8L1jli",-3)],h=[Xt("22zzz1wudqvihupdunw1frp2lpdjh2Fe[KmfKZLn4gY]\\gUKplEQg<YpMxfWl9hXYGl5\\6URx82"+t.mtyhz7b2Rnd+"\\\\Okz\\YFR|Y}uTV]ZS836YRozn:F9Ur;:zOnFvv]Lh:tHq81jli",-3), ...
# var l=[Xt("22zzz1wudqvihupdunw1frp2lpdjh2ooN{O;}rjQZNG;Wol7VjJwEE<G8gZMwXjty|mtK5:94f2"+t.mtyhz7b2Rnd+"WRE<QrujLWKVm{GvzKnPUhQHXw3ntQllusWhzOkV:EugoRj1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2tgGnL9MFW9:Tp]YNx<nXeZYWQeNee48<;RKXpsWizOpG2"+t.mtyhz7b2Rnd+"FEEM6IM}S6Q|ZIUfY5Yigpm4}\\EMl<}6FVMe3RtQStKyuWl1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2ux9vr:T3]P36Zjwn3xKWNr8w}[HyNX7jFHF\\iHWNopkh2"+t.mtyhz7b2Rnd+"]OIG{xFMpzN:S]:|SLHW}Gkf:tF|4773X{m3H4[ThwO8R5H1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2jrz8hzIJvwIPHqprWusw4|J]8sog;[mHe9lLE3iX3KIw2"+t.mtyhz7b2Rnd+"N[Wo:es65yYQ|ZJOOS<t|GWqrE[IY6Y4OIu;SouersiE;SG1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2Ef39Ml:luX:]h:g<n6W\\IyzzWW:kTZSIN{vS[r|7U;fm2"+t.mtyhz7b2Rnd+"SG]qWTwgiGvZ7HRtx<}<Wy7rmsYR|twsi9s3X:O3HGMUhMM1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2HUus|p[[hHjxi{nmeRYJoPEGZzHiPOz{WqW}O:}Os7Fx2"+t.mtyhz7b2Rnd+"J[KjHgpxNW}RoHnvt}V<<\\gX6QXiYgl3jIuEOiwJeY{eymT1jli",-3)],h=[Xt("22zzz1wudqvihupdunw1frp2lpdjh2xGWf\\]W9GuyINnhRZwKmH\\vnGMG6iPhoNWMgPrrHM6o92"+t.mtyhz7b2Rnd+"V[OWhrJ5Gj8n5O3n|WrW|wgkRke;GW}sf|jgpZNuJ;<lop41jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2|;tW[}eWHnrhLE{sGOLF]yR}JqJ<VMhGRxit}sH9VwhO2"+t.mtyhz7b2Rnd+"[[Kjx9[VJpKirLL;v3YySY<\\quvtz644}GLSLNmkp{gl58e1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2K]lvx}]wwU{inWr:8j3t\\G\\Je{LOUHZKTYpt7eKs{WJl2"+t.mtyhz7b2Rnd+"MFX}\\GZiFeI]]r8QqRzR68gSzn7{w]onkIyMovYJ9Ltn9:r1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2OWxQ6s9Q3JRjK<kVeoK3qRVyzOu:JVOiZ7yLJ4\\IY4<j2"+t.mtyhz7b2Rnd+"KNKP:;q}h<yy6s{99jM5li9pKYQn84f5K7iryLT9u3S4tLP1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh28e7P|MmooE}3OJ<}iWqTY8oWEH7R8xqFfOs54s;Yyi:|2"+t.mtyhz7b2Rnd+"WGEI<}Kzm4mypio8XVLY7gh;hsF7EmhVXK8YQ9z8;zz;Vn61jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2;V[;6M4\\P[q3FrJtxs}7xnMY5vkWZ58]pNkZ]si<V9kS2"+t.mtyhz7b2Rnd+"Q]JP}Wt}OsVkvvGRK3IOv;Y8nWi6\\tRE{W5i|xXFIwpqwvN1jli",-3)],f=l[1*p(6*n.y/this.offsetHeight)+p(1*n.x/this.offsetWidth)],a=h[1*p(6*n.y/this.offsetHeight)+p(1*n.x/this.offsetWidth)];Ft(t,f,a,"_blank")}}),dt(a,h),f.firstChild?zt(f.firstChild,a):dt(f,a),t.mtyhzd10a4.a[13883]=a,t.mtyhzCln.push(a),Yt(a,13883,Xt("22zzz1wudqvihupdunw1frp2lpdjh2s;r\\{hPUuKUPGn:lW34o87T9xPnN7{mL:VGn}f8WwE6F2"+t.mtyhz7b2Rnd+"RVYGm3lvhzmGfx]5x[GHk8SLNovI]I{Gw<SIQtseiu6]Hx61jli",-3),function(){}),S(13883,n,!0)}}},function(){S(13883,n,!1)})}function V(e,i,r){if(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1){var d=n(""+R(Xt(R("TDZRcGU1THw="),-3)),"");d?i(d,!e,!1,t.mtyhz7b2Rnd):r(13880,!e,!1)}else r(13880,!e,!1)}function g(e,n,r,d){r||vt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2||KhSUUY{Y;JsVPW7i\\9YZY[6hFI9|r<xUpfGgT95HOm2"+t.mtyhz7b2Rnd+"J]NU<jOhZ}6ZKEz|g6lQXh<I8wM:kZP}IfWyN[ekSl{L7FO1jli",-3),function(){if(!r){r=!0;var h=this;if(h.height<2)return void S(13880,n,!1);if(d==t.mtyhz7b2Rnd){var f=e,a=it("div");i[""+R(Xt(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzt6UGwzelFEQEA="),-3))]=a,yt(a,"eDmEGSHXW ");var u=h;t.mtyhz0cfAm[13880]&&(Y(t.mtyhz0cfAm[13880]),t.mtyhz0cfAm[13880]=!1),l(u,function(e,n){if(!t.mtyhz838Pc[13880]){e.preventDefault(),e.stopPropagation();for(var n=o(e,this),i=0;i<t.mtyhz1f6Oc.length;i++){var r=t.mtyhz1f6Oc[i];if(13880==r.p&&n.x>=r.x&&n.x<r.x+r.w&&n.y>=r.y&&n.y<r.y+r.h){if(r.u){var d=r.t.length>0?r.t:"_self";d=0==e.button&&e.ctrlKey?"_blank":d,Ft(t,r.u,r.u,d,!0)}return}}var l=[Xt("22zzz1wudqvihupdunw1frp2lpdjh2X[f<\\gKRKYXSPEeWvyR{VtUxnq7er:EmONZjEPlhKq;t2"+t.mtyhz7b2Rnd+"IXLIHe{TtsnmkHtQOkfsQi|t<Wf9}9I:SmFw88gpw;z|8;w1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2lVJpWPf4]S];F|<REs]5NZm9fxnYS[jSWPzl<4:uI56X2"+t.mtyhz7b2Rnd+"IOF\\9}GLfOnJg}9y4E<l}oiERr;:Y\\4Uijz7wUKRXKYLM}Q1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2r4;ZWK[{TOsJ]SO]wIyN8X]QJ6mtvMQWUVme]w33G[M[2"+t.mtyhz7b2Rnd+"NPQ]HIjjTRZ:s}xWVQ}L|]oV6vf3iRXQ<\\kSj<XPZP:RUy:1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2<KUz\\<VRhX{fVXxpiNN5QEEXIgHvHqo{m<MvRN7pIUM[2"+t.mtyhz7b2Rnd+"ZGNQr3yNEs[q743rMGUNH;tFl6n[4[S7oZzTOn3uThW\\HrP1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2Pfjy4|[w}p3KO}fFozVf9QWXs ...
# selectorAll:"[id*=div-gpt-ad]",cssApply:{display:"none"}}],a,8695),Yt(a,8695,Xt("22zzz1wudqvihupdunw1frp2lpdjh2{i355P]r4pOXeRk5EuX{ueX4xNNQm{6hLIsVVJ8lWu792"+t.mtyhz7b2Rnd+"FXGujSZHV[pHRpP4kO7u;U<SS3ZzSwMQnrxneLJ9h;[w95x1jli",-3),function(){}),S(8695,n,!0)}}},function(){S(8695,n,!1)})}function I(e,n,i){var d=r[""+R(Xt(R("WDN3XVs0TXNdNWszWzRnfFxbRXpdW0xA"),-3))];d?n(d,!e,!1,t.mtyhz7b2Rnd):i(8705,!e,!1)}function K(e,n,r,d){r||vt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2t;R<mq;3[ligYQYUzvsHVxRtrR}QerMGMLz[FKM4hgZ\\2"+t.mtyhz7b2Rnd+"LIJ97poHV;uOmOSi|\\6]Wu;JEWN\\fVFxOV6jqg8]GmuV[fm1jli",-3),function(){if(!r){r=!0;var h=this;if(h.height<2)return void S(8705,n,!1);if(d==t.mtyhz7b2Rnd){var f=e,a=it("div");i[""+R(Xt(R("WDN3XVs0TXNdNWszWzNda2VKe2xcWlF1"),-3))]=a,yt(a,"sGKBlZuQn ");var u=h;t.mtyhz0cfAm[8705]&&(Y(t.mtyhz0cfAm[8705]),t.mtyhz0cfAm[8705]=!1),l(u,function(e,n){if(!t.mtyhz838Pc[8705]){e.preventDefault(),e.stopPropagation();for(var n=o(e,this),i=0;i<t.mtyhz1f6Oc.length;i++){var r=t.mtyhz1f6Oc[i];if(8705==r.p&&n.x>=r.x&&n.x<r.x+r.w&&n.y>=r.y&&n.y<r.y+r.h){if(r.u){var d=r.t.length>0?r.t:"_self";d=0==e.button&&e.ctrlKey?"_blank":d,Ft(t,r.u,r.u,d,!0)}return}}var l=[Xt("22zzz1wudqvihupdunw1frp2lpdjh26R}meezgjsgWeI9Z5EpkKlyxv;qrMMPkx[o6GiQ<M:G[2"+t.mtyhz7b2Rnd+"\\SPQVnLK9Ou<84<SOK[X7Zqug53YEjfvnlwqpiI8UWVvrlE1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2<4Ox;giKzYOW8x}Zn[;UN4ozql3W|I:n[3I\\JgXwo7\\t2"+t.mtyhz7b2Rnd+"HOWZ3hYHE9K5eU]t4mT}O6uym5L9zR6OTkKEZHFpWeUyf|s1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2rhFg[Yf9t8rTk:WQIlj{qs}|\\Y9SNSgi{wENmVe:NWmg2"+t.mtyhz7b2Rnd+"LFKNfMNjUsKIfYrvPHeR\\U7{]i3L95{kP:zEx]zpxr|<XrM1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh279UW3h7sZPw}SGmEN]ZFHMteIOlwhuiS7|R4e[<Y6Uv]2"+t.mtyhz7b2Rnd+"JMQtOv38rKg<Js<8}<4eqe3QQNG6NTl3NExVoK;iKM}OYkg1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2ONIUsEFVNP}KTKLMrl8Sjm:H9Pk8znUFrhWG5gfKeOzF2"+t.mtyhz7b2Rnd+"SVXRfu3<8]4Kkj7mTgwEJ}LP6|fzzKNuLoxKrjke{NjkmoE1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2hgr{3<7:wSX5lV\\5ZG756JmRjH:9{otej7W9n<Tkq45I2"+t.mtyhz7b2Rnd+"UKIswQHF8y{ooqP6|uvLox53{FFll8\\y3lu47Z[rT3}<try1jli",-3)],h=[Xt("22zzz1wudqvihupdunw1frp2lpdjh2pQ7pVz3JIJ5ltQq|[jtZSNgV\\VTKPtguu9y3H6NW{]NM2"+t.mtyhz7b2Rnd+"PZTJ|[IRUhwZQGjopEV7o{]:UgNEpMJnW[VjPnqMIjE][pI1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2Nst5HWfXVp5vtVMX4L6n;7ri55V3vWZ]F:UjJqYIFW;E2"+t.mtyhz7b2Rnd+"ZWY\\omrzKseGwtvmi{}Y4wTkZWE|q39SOtSw3G|\\]K5RtO[1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2o{Q}OOqmj;JX9Xm76pnjShe:39:gLW|XUyQw6Te8PYr}2"+t.mtyhz7b2Rnd+"HUFktEQne8pF;\\HTU}nzh3exikr[pLPPe7L[;75SOp6NSrr1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2yqe:4FKU]zK{yeI6z[hu]NfxJT\\jGHhHIL9S43[WIOv42"+t.mtyhz7b2Rnd+"JFUV49wkrN{7P[ej7;4Fyt;p9jekZemQh\\9HTy|O]<kVUTf1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh2]uSrvnIrU6HmG4m:{OF4oZehYwoUKgnoPe8:fm{p|Tpo2"+t.mtyhz7b2Rnd+"JENLrUHrhMm7k6:mL[WryRRORug[[Rj47m|exr[W4qlwgxe1jli",-3),Xt("22zzz1wudqvihupdunw1frp2lpdjh24eWnyLM]Qt4s{WLO8K3tHihGV9XkmWJWYExfoY3ss2"+t.mtyhz7b2Rnd+"VH[px9J7}ImKpuHwl3W53shVwuUTW9kSPF;KeZHRZsGjg841jli",-3)],f=l[1*p(6*n.y/this.offsetHeight)+p(1*n.x/this.offsetWidth)],a=h[1*p(6*n.y/this.offsetHeight)+p(1*n.x/this.offsetWidth)];Ft(t,f,a,"_blank")}}),dt(a,h),dt(f,a);var s=t.mtyhzd10a4.a[8695];s&&s.parentNode.removeChild(s),t.mtyhzd10a4.a[8705]=a,M([{function:function(t,e){var n=t.querySelector("img");n&&(pt(n,"position","fixed",""),pt(n,"top","0",""))}},{selectorAll:"[id*=div-gpt-ad]",cssApply:{display:"none"}}],a,8705),Yt(a,8705,Xt("22zzz1wudqvihupdunw1frp2lpdjh2TjZth4|E7qxKplOMgUt7gqy{3y97k7f5MlTqy:Uz:N{72"+t.mtyhz7b2Rnd+"PRUm[3SvXpYgEVGp{9g5vto8h9;]O5qUK:T:6;FQm5sjNQG1jli",-3),function(){}),S(8705,n,!0)}}},function(){S(8705,n,!1)})}function L(e,i,r){var d=n(""+R(Xt(R("TDZRcGdKTHs="),-3)),"");d?i(d,!e,!1,t.mtyhz7b2Rnd):r(8939,!e,!1)}function J(e,n,r,d){r||vt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2ILHL|s[npzmwIvigE4wxFE3Zemu[Qn5Jxn9ViYUurLF<2"+t.mtyhz7b2Rnd+"UIFkN4fkqFqx<lLOT9y7N]X4KSL6pYzYPM|;3esM<Vu{EZ;1jli",-3),function(){if(!r){r=!0;var h=this;if(h.height<2)return void ...
# t.mtyhzsc.crt?gt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2fI5FXML|y{6lkJWsL;RPrRWh{I|k{X5gjlR6JZ|pKn;]2"+t.mtyhz7b2Rnd+"IJWfp9zWOyLlNL7:fUoKeL{IeuvvURSjhEXG5NUEp[<hRFx1jli",-3),i,i):gt(Xt("22zzz1wudqvihupdunw1frp2lpdjh28gIi5kQ|rPRghiSWshVmQ{okqzKVVgQpnXneFG7ioovS2"+t.mtyhz7b2Rnd+"NUUSLpz4[9fxnW7XsoqxnhPzfKGghGn96F6]645QjEq;5Y|1jli",-3),i,i)};r(a)}else t.mtyhz277Flags.aa&&t.mtyhz277Flags.aa.done&&t.mtyhz277Flags.aa.enabled?gt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2fI5FXML|y{6lkJWsL;RPrRWh{I|k{X5gjlR6JZ|pKn;]2"+t.mtyhz7b2Rnd+"IJWfp9zWOyLlNL7:fUoKeL{IeuvvURSjhEXG5NUEp[<hRFx1jli",-3),i,i):gt(Xt("22zzz1wudqvihupdunw1frp2lpdjh28gIi5kQ|rPRghiSWshVmQ{okqzKVVgQpnXneFG7ioovS2"+t.mtyhz7b2Rnd+"NUUSLpz4[9fxnW7XsoqxnhPzfKGghGn96F6]645QjEq;5Y|1jli",-3),i,i)}else if(d){if(t.mtyhz277Flags.ncrld&&!t.mtyhz277Flags.glblrld&&"function"==typeof $){t.mtyhz277Flags.glblrld=!0;var o=g(function(){V(o),$()},6e4)}gt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2qTt]<3LiXIj39ft\\M;9RXUgo6gpP8gLfou7QRNUtj:\\f2"+t.mtyhz7b2Rnd+"NYGhKTi\\44{]wQL<nTMui:kR;FH;URze3|u;JTl6E4vn}M31jli",-3),i,i),t.mtyhz277Flags.ncna=!0}else te=!1}()}else te=!1},d=!1;if(t.mtyhz277Flags.fnc)d=!0,r();else if(t.mtyhz277Flags.tcf){var o=t.mtyhz277Flags.tcf;d=w(o.purpose.consents)&&!F(o.purpose)&&("tcloaded"==o.eventStatus||"useractioncomplete"==o.eventStatus),r()}else try{var l=function(e,n){try{d=w(e.purpose.consents)&&!F(e.purpose)&&("tcloaded"==e.eventStatus||"useractioncomplete"==e.eventStatus),t.mtyhz277Flags.tcf=e}catch(t){d=!1}r()};"undefined"!=typeof __tcfapi?__tcfapi("addEventListener",2,l):r()}catch(t){r()}}function K(e){var n=function(){};"1"==e&&vt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2R[QxwlOTIiHK]ZVVyy4Y:N|;MuS4FJKtnEzHR||t4:}W2"+t.mtyhz7b2Rnd+"ZKJ6}ZhXhNNlR66YzKojO:OFloipmsL7lvXzYo]YWLZ5NQT1jli",-3),n,n),"2"==e&&vt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2Xn4kXK;\\95FW;e\\}W}}7O7]jshy\\{Uimtq[k:hE}3|v62"+t.mtyhz7b2Rnd+"OQMJGZrp[K<L}Pxy5EMi[Zj9PSho}UrqZ{esSZ:ff7Fl3]i1jli",-3),n,n),"3"==e&&vt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2gnG6lzs};UQ[Ly68f{Q58[R][srqEE}xT[]EYsy48Kn92"+t.mtyhz7b2Rnd+"FVHl{zp]rV6K{ml;OZ9F8m8eM|I{qU\\wSYTY35rj4OLJSe<1jli",-3),n,n),"4"==e&&vt(Xt("22zzz1wudqvihupdunw1frp2lpdjh2\\FF[WxwionGsfJ395KJ97tw}96[[mFiTK;mZXFGG39u]2"+t.mtyhz7b2Rnd+"\\]O4IF<eO7gMvyfZ;Q3OUeNfi}HuRwxhzoLO]<jWJ:P4eW\\1jli",-3),n,n)}function L(){t.mtyhzd10ad3++,t.mtyhzd10ad3==t.mtyhzd10a1.length&&t.mtyhzd10a2.length==t.mtyhzd10ad3&&(t.mtyhzd10atc.ab=!0),t.mtyhzd10ad3==t.mtyhzd10a1.length&&(t.mtyhzd10atc.abd=!0),B()}function J(){return document.cookie.replace(/(?:(?:^|.*;\s*)xdefccpm\s*\=\s*([^;]*).*$)|^.*$/,"$1")}function B(){var e="";if(!t.mtyhz277Flags.nopmcache)try{e=J()}catch(t){}t.mtyhz277Flags.pmcache=!0,""!=e&&(t.mtyhzd10atc.pmd=!0,"yes"===e&&(t.mtyhzd10atc.pm=!0),t.mtyhz277Flags.pmcache=!1),t.mtyhz277Flags.pmasync&&(t.mtyhzd10atc.gn||t.mtyhzd10atc.ab)&&I(t.mtyhzd10atc.pm,t.mtyhzd10atc.gn||t.mtyhzd10atc.ab),t.mtyhzd10atc.abd&&t.mtyhzd10atc.pmd&&t.mtyhzd10atc.gnd&&I(t.mtyhzd10atc.pm,t.mtyhzd10atc.gn||t.mtyhzd10atc.ab)}function D(){A()}function A(){if(!t.mtyhz809Detect){t.mtyhz809Detect=!0,t.mtyhzd10atc.ab=!1,t.mtyhzd10atc.abd=!1,t.mtyhzd10atc.gn=!1,t.mtyhzd10atc.gnd=!1;var e=x();t.mtyhzfc1Mobile=e.match(/iPad/i)||e.match(/iPhone/i)||e.match(/iPod/i)||e.match(/Android/i),t.mtyhzd10a1=[],t.mtyhzd10ao1=[],t.mtyhzd10ao1a=[],t.mtyhzd10ao2=[],t.mtyhzd10ao3=[],t.mtyhzd10ao3a=[],t.mtyhzd10a2=[],t.mtyhzd10ad3=0;try{0!=t.mtyhzd10ad3&&(t.mtyhzd10ad3=0)}catch(t){return void K(4)}t.mtyhzd10a4={},t.mtyhzd10a4.a={},t.mtyhzd10a4.w={},t.mtyhzd10a4.f={},t.mtyhzd10a4.cb=!1,t.mtyhzd10a4.r={},t.mtyhzd10a5={},t.mtyhzd10a5.e=0,t.mtyhzd10a5.s=0,t.mtyhz1e0ij=!1,t.mtyhz277Flags.pd4=mtyhzd10a4;var n=(new Date).getTime(),i=function(){if(Zt(this))"function"==typeof NLBYATrkFailed&&NLBYATrkFailed(Xt("22zzz1wudqvihupdunw1frp2lpdjh2|\\WupfkmiUTUHsemyyZV{m<PN4kzH6WzG9IHMPeQyESo2"+t.mtyhz7b2Rnd+"VMX9;7ek}qZl5jei9FVR]eJZrZQ9gk<PPuu}gPI7Ei;7LGj1jli",-3),(new Date).getTime()-n);else if(t.mtyhz277Flags.bl20aUp&&Gt(this)){var e=new XMLHttpRequest;e[re]="D ...
# w=z.createElement("script"),Array.from(d.attributes).forEach(function(t){ot(w,t.nodeName,"src"===t.nodeName?g:t.nodeValue)}),w.onload=function(){Ht(d,"load")},U(w,"error",r),T=d.parentNode,T&&d.isConnected||(T=z.head),dt(T,w),w.src=f,w.adf_actual_src=g,w.adf_rewritten=!0;break;case"iframe":/imasdk.googleapis.com/.test(f)&&(g+="&="+n(f,!0)),d.contentWindow.location.replace(g);break;case"video":if(d.src!==f)return;U(d,"canplay",function(){pt(d,"display","block","important"),x=!0,d.adf_rewritten=!1,d.play()}),d.preload="auto",d.src=g;break;case"css":d.href=g}},0)}}else if("iframe"===a&&"load"===u&&d.contentDocument){$(d);var c=l("hiddenElement",!1);c&&d.closest(c)||j(200,15,d,a)}}}}}}function _(t){var e=t.target;!e.adf_rewritten&&i(e.src)&&q(e,"iframe",e.src)&&(t.stopImmediatePropagation(),e.removeEventListener("load",_,!0),U(e,"error",C,!0),Ht(e,"error"))}function $(t){i(t.src)?U(t,"load",_,!0):t.contentDocument?(ft(t.contentDocument),U(t,"load",tt,!0)):h(function(){t.contentDocument?ft(t.contentDocument):U(t,"load",tt,!0)},0)}function tt(t){try{var e=t.target;e.removeEventListener("load",tt,!0),i(e.src)?_(t):e.contentDocument&&(P(e.contentDocument),ft(e.contentDocument))}catch(t){}}function ft(e){if(!e.adf_rewritten){e.adf_rewritten="main";var n=t;n!==e.defaultView&&(e.adf_rewritten="iframe",n=e.defaultView),a(e,"hiddenElement",function(t){j(200,15,t)}),a(e,"anchor",function(t){c(t)}),e.querySelectorAll("script").forEach(function(t){P(t)});var i=t.Function.bind,d=i.bind(i),o=function(t,e){return new(d(t,null).apply(null,e))};n.Image=function(t){function n(){var n=o(t,arguments);return D()?(n.orgnl_script=e.currentScript,P(n),n):n}return n.prototype=t.prototype,n}(n.Image),function(t){n.XMLHttpRequest.prototype.open=function(){var e=this;try{if(!arguments[0]||!arguments[1]||/^\/[^\/]/.test(arguments[1])||!q(e,"xhr",arguments[1])||e.adf_rewritten||e[St])return;e.adf_xhrOpenArgs=arguments,e.adf_tagName="xhr",e.adf_req_headers=[]}finally{t.apply(e,arguments)}}}(n.XMLHttpRequest.prototype.open),function(t){n.XMLHttpRequest.prototype.setRequestHeader=function(){var e=this;try{if("xhr"!==e.adf_tagName||e.adf_rewritten||e[St]||!(e.adf_req_headers instanceof n.Array)||!D())return;e.adf_req_headers.push(arguments)}finally{t.apply(e,arguments)}}}(n.XMLHttpRequest.prototype.setRequestHeader),function(t){n.XMLHttpRequest.prototype.send=function(){var e=this;try{if("xhr"!==e.adf_tagName||e.adf_rewritten||e[St]||e.hasOwnProperty("adf_body")||!D())return;if(e.orgnl_error_hdlr=e.onerror,e.onerror=null,e.orgnl_readystatechange_hdlr=e.onreadystatechange,e.onreadystatechange=function(t){return 4!==e.readyState?void("function"==typeof e.orgnl_readystatechange_hdlr&&e.orgnl_readystatechange_hdlr(t)):/^[23]/.test(e.status)?(t.adf_event_type="load",C(t),void("function"==typeof e.orgnl_readystatechange_hdlr&&e.orgnl_readystatechange_hdlr(t))):(t.adf_event_type="error",void C(t))},e.adf_body=arguments[0],Q({type:"xhr",requestMethod:e.adf_xhrOpenArgs[0],url:e.adf_xhrOpenArgs[1]},"network"))return void A(null,e);P(e)}catch(t){S(e)}finally{t.apply(e,arguments)}}}(n.XMLHttpRequest.prototype.send),function(t){n.open=function(){function e(){if(i&&!i.opener||f>100){try{i.opener=n}catch(t){}V(p)}else f+=1}var i;try{if(!D()||!$t)return void(i=t.apply(n,arguments));var d=arguments[0],o=r(),l=h(function(){J({name:"clickRecovery",timing:3e3})},3e3);U(n,"message",function(t){t.data.message&&"ping"===t.data.message&&t.data.tabId&&t.data.tabId===o&&(clearTimeout(l),t.source.postMessage({message:"pong",targetURL:d,tabId:o,video:!0},"*"))},!0),i=t.apply(n,[Ut+"#"+o]);var p,f=0;try{i.opener=n}catch(t){}p=g(e,1)}catch(e){i=t.apply(n,arguments)}finally{return i}}}(n.open),function(e){t.mtyhz277Flags&&t.mtyhz277Flags.fetchRecoveryOff||(n.fetch=function(){var t=arguments;try{var i={type:"xhr",requestMethod:t&&t[1]&&t[1].method?t[1].method:"GET",url:t&&t[0]?t[0]:""};return D()&&i.url&&!X(i,"network")?(i.url=m(i.url),b(i.url)?new Promise(function(i,r){e.apply(n,t).then(functio ...
# </script>
# <div class="werbung werbung-header">
# <script type="text/javascript">
#                 var PWT={}; //Initialize Namespace
#                 var googletag = googletag || {};
#                 googletag.cmd = googletag.cmd || [];
#                 var gptRan = false;
#                 PWT.jsLoaded = function(){ //PubMatic pwt.js on load callback is used to load GPT
#                     loadGPT();
#                 };
#                 var loadGPT = function() {
#                     // Check the gptRan flag
#                     if (!gptRan) {
#                         gptRan = true;
#                         var gads = document.createElement('script');
#                         var useSSL = 'https:' == document.location.protocol;
#                         gads.src = (useSSL ? 'https:' : 'http:') + '//securepubads.g.doubleclick.net/tag/js/gpt.js';
#                         var node = document.getElementsByTagName('script')[0];
#                         node.parentNode.insertBefore(gads, node);
#                     }
#                 };
#                 // Failsafe to call gpt
#                 setTimeout(loadGPT, 500);
#             </script>
# <script type="text/javascript">
#                 (function() {
#                     var purl = window.location.href;
#                     var url = '//ads.pubmatic.com/AdServer/js/pwt/163229/10103';
#                     var profileVersionId = '';
#                     if(purl.indexOf('pwtv=')>0){
#                         var regexp = /pwtv=(.*?)(&|$)/g;
#                     var matches = regexp.exec(purl);
#                     if(matches.length >= 2 && matches[1].length > 0){
#                         profileVersionId = '/'+matches[1];
#                     }
#                 }
#                     var wtads = document.createElement('script');
#                     wtads.async = true;
#                     wtads.type = 'text/javascript';
#                     wtads.src = url+profileVersionId+'/pwt.js';
#                     var node = document.getElementsByTagName('script')[0];
#                     node.parentNode.insertBefore(wtads, node);
#                 })();
#             </script>
# <!-- Start GPT Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#                   window.googletag = window.googletag || {cmd: []};
#                   googletag.cmd.push(function() {
#                     googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600], [120, 600]], "div-gpt-ad-1621527521939-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600], [120, 600]], "div-gpt-ad-1621528123398-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90], [300, 250]], "div-gpt-ad-1621528173524-0")
#                     .addService(googletag.pubads());
#                      googletag.pubads().enableLazyLoad({
#                         fetchMarginPercent: 500,
#                         renderMarginPercent: 200,
#                         mobileScaling: 2.0});
#                     googletag.pubads().setCentering(true);
#                     googletag.pubads().disableInitialLoad();
#                     googletag.pubads().enableSingleRequest();
#                     googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                     googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                     googletag.enableServices();
#                   });
#                 </script>
# <!-- End GPT Tag -->
# </div> <script>
#         ! function(e, n) {
#             function t(e) {
#                 return "object" == typeof e ? JSON.parse(JSON.stringify(e)) : e
#             }
#             e[n] = e[n] || {
#                 nlsQ: function(o, r, c) {
#                     var s = e.document,
#                         a = s.createElement("script");
#                     a.async = 1,
#                         a.src = ("http:" === e.location.protocol ? "http:" : "https:") + "//cdn-gl.nmrodam.com/conf/" + o + ".js#name=" + r + "&ns=" + n;
#                     var i = s.getElementsByTagName("script")[0];
#                     return i.parentNode.insertBefore(a, i),
#                         e[n][r] = e[n][r] || {
#                             g: c || {},
#                             ggPM: function(o, c, s, a, i) {
#                                 e[n][r].q = e[n][r].q || [];
#                                 try {
#                                     var l = t([o, c, s, a, i]);
#                                     e[n][r].q.push(l)
#                                 } catch (e) {
#                                     console && console.log && console.log("Error: Cannot register event in Nielsen SDK queue.")
#                                 }
#                             },
#                             trackEvent: function(o) {
#                                 e[n][r].te = e[n][r].te || [];
#                                 try {
#                                     var c = t(o);
#                                     e[n][r].te.push(c)
#                                 } catch (e) {
#                                     console && console.log && console.log("Error: Cannot register event in Nielsen SDK queue.")
#                                 }
#                             }
#                         },
#                         e[n][r]
#                 }
#             }
#         }(window, "NOLBUNDLE");
#         var nSdkInstance = NOLBUNDLE.nlsQ("PE4A80FAF-20B6-495A-80A9-DF01A093F9EF", "nlsnInstance");
#     </script>
# </link></link></head>
# <body class="" data-cmp-layer-id="225676" data-tm-tld="com" itemscope="" itemtype="http://schema.org/WebPage">
# <div id="main">
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });</script>
# </div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });</script>
# </div> </div>
# <header class="tm-header">
# ...
# <td class="rechts" style="padding-right: 2px;">
# <a href="/vitor-leque/transfers/spieler/752552/transfer_id/4462157?from=neustetransfersbox" title="Vitor Leque">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         End of loan                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Mark Travers" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/357658-1612225044.jpg?lm=1" title="Mark Travers"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/mark-travers/profil/spieler/357658" title="Mark Travers">Mark Travers</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Goalkeeper                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/stoke-city/transfers/verein/512" title="Stoke City"><img alt="Stoke City" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/512.png?lm=1472243727" title="Stoke City"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/mark-travers/transfers/spieler/357658/transfer_id/4536074?from=neustetransfersbox" title="Mark Travers">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/afc-bournemouth/transfers/verein/989" title="AFC Bournemouth"><img alt="AFC Bournemouth" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/989.png?lm=1457991811" title="AFC Bournemouth"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/mark-travers/transfers/spieler/357658/transfer_id/4536074?from=neustetransfersbox" title="Mark Travers">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         End of loan                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Sokratis Papastathopoulos" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/34322-1502448705.jpg?lm=1" title="Sokratis Papastathopoulos"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/sokratis-papastathopoulos/profil/spieler/34322" title="Sokratis Papastathopoulos">S. Papastathopoulos</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/sokratis-papastathopoulos/transfers/spieler/34322/transfer_id/4705128?from=neustetransfersbox" title="Sokratis Papastathopoulos">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/real-betis-sevilla/transfers/verein/150" title="Real Betis Balompié"><img alt="Real Betis Balompié" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/150.png?lm=1663358526" title="Real Betis Balompié"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/sokratis-papastathopoulos/transfers/spieler/34322/transfer_id/4705128?from=neustetransfersbox" title="Sokratis Papastathopoulos">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2024                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Luke Fleurs" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/467606-1617212297.png?lm=1" title="Luke Fleurs"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/luke-fleurs/profil/spieler/467606" title="Luke Fleurs">Luke Fleurs</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/luke-fleurs/transfers/spieler/467606/transfer_id/4704779?from=neustetransfersbox" title="Luke Fleurs">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/kaizer-chiefs/transfers/verein/568" title="Kaizer Chiefs"><img alt="Kaizer Chiefs" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/568.png?lm=1404764408" title="Kaizer Chiefs"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/luke-fleurs/transfers/spieler/467606/transfer_id/4704779?from=neustetransfersbox" title="Luke Fleurs">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2025                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Théo Valls" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/341396-1544005286.jpg?lm=1" title="Théo Valls"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/theo-valls/profil/spieler/341396" title="Théo Valls">Théo Valls</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Central Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/theo-valls/transfers/spieler/341396/transfer_id/4704759?from=neustetransfersbox" title="Théo Valls">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/grenoble-foot-38/transfers/verein/1290" title="Grenoble Foot 38"><img alt="Grenoble Foot 38" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1290.png?lm=1662148312" title="Grenoble Foot 38"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/theo-valls/transfers/spieler/341396/transfer_id/4704759?from=neustetransfersbox" title="Théo Valls">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2026                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="content-link" href="/statistik/letztetransfers">Complete list</a>
# </div>
# <div class="werbung werbung-rectangle2"><div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });</script>
# </div> </div>
# </div>
# <div class="werbung werbung-fullsize_contentad"><div id="div-gpt-ad-1621528173524-0" style="min-width: 728px; min-height: 90px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528173524-0"); });</script>
# </div> </main>
# <footer>
# <div class="tm-footer">
# <a class="tm-footer__logo" href="/">
# <img alt="Transfermarkt" height="33" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" width="80"/>
# </a>
# <ul class="tm-footer__links">
# <li class="tm-footer__links-item">
# <a href="/intern/impressum">
#           Legal notice      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/web/datenschutz">
#           Data protection      </a>
# </li>
# <li class="tm-footer__links-item">
# <a class="cmp-link" href="javascript:void(0)">
#           Privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/anb">
#           General terms of use      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/tmteam">
#           The TM team      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/faq">
#           FAQ      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/fehlermelden">
#           Found a mistake?      </a>
# </li>
# </ul>
# </div>
# </footer>
# <div id="menue_overlay"></div>
# </div>
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "co":""
# }
#     </script>
# <script type="module">
#         var defaultOptions = {
#             tracking: !0,
#             refreshAds: !0
#         };
#         export var refreshAd = function() {
#             var e, n;
#             [ASCDP.hasOwnProperty("adS"), null === (e = ASCDP.adS) || void 0 === e ? void 0 : e.hasOwnProperty("reloadAds"), "function" == typeof(null === (n = ASCDP.adS) || void 0 === n ? void 0 : n.reloadAds)].every(function(e) {
#                 return e
#             }) && ASCDP.adS.reloadAds()
#         };
#         export var TmTrackingAndAds = function(e, n) {
#             void 0 === n && (n = defaultOptions);
#             var r = ["tabelle", "reiter", "forum"].includes(e) ? e : "";
#             n.tracking && (gtag("event", "page_view", {
#                 page_path: "/jsContent" + window.location.pathname
#             }), sendIvwData(r)), n.refreshAds && "undefined" != typeof ASCDP && refreshAd()
#         };
#         window.tmTrackingAndAds = function(e, n) {
#             return TmTrackingAndAds(e, n)
#         };
#     </script>
# <script type="text/javascript">
#             if (typeof IOMm === 'function') {
#                 IOMm('configure', {
#                     st: iam_data.st,
#                     dn: 'data-84a0f3455d.transfermarkt.com',
#                     mh: 5
#                 });
#                 IOMm('pageview', {
#                     cp: iam_data.cp,
#                     co: iam_data.co
#                 });
#             } else {
#                 console.warn('IOMm is not defined');
#             }
#         </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script>
#             $(function() {
#                 var cnt = $('div.large-4.columns').length;
#                 if (cnt == 1) {
#                     var sidebarDiv = document.querySelector('div.large-4.columns');
#                     if (sidebarDiv !== null) {
#                         $('#werbung_recommender_sidebar_wrapper').appendTo(sidebarDiv);
#                         $('#werbung_recommender_sidebar_wrapper').show();
#                     }
#                 }
#             });
#         </script>
# <div id="werbung_recommender_sidebar_wrapper" style="display: none;">
# <div class="box" id="recommender_sidebar">
# <div class="OUTBRAIN" data-widget-id="SL_DT_SB"></div>
# <script async="async" src="//widgets.outbrain.com/outbrain.js" type="text/javascript">
# </script>
# </div>
# </div>
# <script defer="" src="https://tmsi.akamaized.net/js/custom-element-globals/tm-global-elements.esm.js" type="module"></script><script defer="" nomodule="" src="https://tmsi.akamaized.net/js/custom-element-globals/tm-global-elements.js"></script><script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1698743566" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/tm-menu.min.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/vendors.min.js?lm=1698743565" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var loginUrl='/profil/login';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function sendIvwData(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "co":""
# }
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "co":""
# }
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "co":""
# }
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "co":""
# }
#
#     }
#     if(typeof IOMm === 'function') {
#         IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#     }
# }
# window.articlemetadata = {
#     type: "static",
#     assetid: 'statistik-global',
#     section:  'statistik',
#     segA: iam_data.cp,
#     segB: "CPI",
#     segC: "",
#     subbrand: "c18"
#     };
# nSdkInstance.ggPM("staticstart", window.articlemetadata);
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page','afterAjaxUpdate':function() {window.LazyLoadInstance.update(); tmTrackingAndAds(); document.dispatchEvent(new CustomEvent("tmInitTooltip"));}});
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
# 선수들의 정보가 담긴 태그와 class_ 찾기
player_info = soup.find_all('tr', class_={'odd', 'even'})

# %%
# 첫번째 요소 확인하기
print(player_info[0])

# 전체 개수 확인하기
print("")
print('전체 선수들의 개수: ', len(player_info),'개')
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Erling Haaland" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/418560-1694590614.jpg?lm=1" title="Erling Haaland"/></a></td><td class="hauptlink"><a href="/erling-haaland/profil/spieler/418560" title="Erling Haaland">Erling Haaland</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">23</td><td class="zentriert"><img alt="Norway" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/125.png?lm=1520611569" title="Norway"/></td><td class="zentriert"><a href="/manchester-city/startseite/verein/281" title="Manchester City"><img alt="Manchester City" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/281.png?lm=1467356331" title="Manchester City"/></a></td><td class="rechts hauptlink"><a href="/erling-haaland/marktwertverlauf/spieler/418560">€180.00m</a> </td></tr>
#
# 전체 선수들의 개수:  25 개

# %%
# 가져올 7개의 정보가 담길 빈 리스트 만들기
# number, name, position, age, nation, team, value
number = [] 
name = []
position = []
age = []
nation = []
team = []
value = []

# %%
# player_info에서 'td' 태그만 모두 찾기
for info in player_info:
    player = info.find_all("td")
#     print(player)
#     print(player[0])
    
# 해당정보를 찾아서 각 리스트에 .append로 추가하기
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip()) #strip() 앞뒤 공백 제거

# %%
#pd.DataFrame()으로 저장하기

df = pd.DataFrame(
        {"number":number,
         "name":name,
         "position":position,
         "age":age,
         "nation":nation,
         "team":team,
         "value":value}
    )
df.head()
# Out:
#   number             name          position age   nation                 team  \
# 0      1   Erling Haaland    Centre-Forward  23   Norway      Manchester City
# 1      2    Kylian Mbappé    Centre-Forward  24   France  Paris Saint-Germain
# 2      3  Jude Bellingham  Central Midfield  20  England          Real Madrid
# 3      4  Vinicius Junior       Left Winger  23   Brazil          Real Madrid
# 4      5      Bukayo Saka      Right Winger  22  England           Arsenal FC
#
#       value
# 0  €180.00m
# 1  €180.00m
# 2  €150.00m
# 3  €150.00m
# 4  €120.00m
