# %%
# 라이브러리 import
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# 구글 검색창에 입력한 my users agent 정보를 headers에 설정
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Whale/3.22.205.26 Safari/537.36'}

# 크롤링할 페이지가 있는 주소값을 넣기
url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r = requests.get(url, headers=headers)
r.status_code
# Out:
# 200

# %%
# 분석할 html 소스 가져오기
soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"gdpr":{"consentLanguage":"en"},"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport"/>
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" property="og:url"/>
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.transfermarkt.ch/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="world" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.ro/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ro" rel="alternate"/>
# <link href="https://www.transfermarkt.gr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="el-GR" rel="alternate"/>
# <link href="https://www.transfermarkt.co.kr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ko-KR" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.pe/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.my/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1698743558" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1698743576" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1698743576" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1698743566" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1698743566" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1698743566" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1698743565" type="text/javascript"></script>
# <title>Most valuable players | Transfermarkt</title>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/manager/base/es6/bundle.js" id="IOMmBundle" rel="preload"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" rel="preload"/>
# <script src="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" type="text/javascript"></script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#     </script>
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 01111018 */ !function(e,t){function i(e,t){var i=Ue(e);if(!i)return i;if(""!=t)for(var d=0;d<t.length;d++){var n=a(t,d);"^"==n&&(i=i.parentNode),"<"==n&&(i=i.previousElementSibling),">"==n&&(i=i.nextElementSibling),"y"==n&&(i=i.firstChild)}return i}function d(e,t){var i=ue(t);return{x:e.clientX-i.left,y:e.clientY-i.top}}function n(e){for(var t=0,i=0;e;)t+=e.offsetLeft+e.clientLeft,i+=e.offsetTop+e.clientTop,e=e.offsetParent;return{x:t,y:i}}function o(e,t){var i=0,d=0,o=n(t);return(e.pageX||e.pageY)&&(i=e.pageX,d=e.pageY),(e.clientX||e.clientY)&&(i=e.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,d=e.clientY+document.body.scrollTop+document.documentElement.scrollTop),i-=o.x,d-=o.y,{x:i,y:d}}function r(e,t){return ae(t)?d(e,t):o(e,t)}function l(e,t){e.addEventListener?U(e,"click",t,!0):e.attachEvent&&e.attachEvent("onclick",function(){return t.call(e,window.event)})}function p(t,i){return e[j("c2V0VGltZW91dA==")](t,i)}function f(e){return parseInt(e.toString().split(".")[0],10)}function a(e,t){return e[t]}function u(){return Ae=(Je*Ae+De)%Be}function s(){return u()/(Be-1)}function h(){return s()}function c(e,t){return e>t?e:t}function w(){for(var e="",t=65;t<91;t++)e+=R(t);for(var t=97;t<123;t++)e+=R(t);return e}function R(e){return a(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+a("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",e-32)}function j(e){var t,i,d,n,o,r,l,p=w()+"0123456789+/=",f="",u=0;for(e=e.replace(/[^A-Za-z0-9\+\/\=]/g,"");u<e.length;)n=p.indexOf(a(e,u++)),o=p.indexOf(a(e,u++)),r=p.indexOf(a(e,u++)),l=p.indexOf(a(e,u++)),t=n<<2|o>>4,i=(15&o)<<4|r>>2,d=(3&r)<<6|l,f+=R(t),64!=r&&(f+=R(i)),64!=l&&(f+=R(d));return f}function x(e){for(var t=w()+"0123456789+/=",i=e.length-1,d=-1,n="";d<i;){var o=e.charCodeAt(++d)<<16|e.charCodeAt(++d)<<8|e.charCodeAt(++d);n+=t[o>>>18&63]+t[o>>>12&63]+t[o>>>6&63]+t[63&o]}var r=e.length%3;if(r>0)for(n=n.slice(0,r-3);n.length%4!=0;)n+="=";return n}function b(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(e){return"unknown"}}function U(t,i,d,n){n=n||!1;try{t.addEventListener(i,d,n),e.djwioClne.push([t,i,d,n])}catch(o){t.attachEvent&&(t.attachEvent("on"+i,d),e.djwioClne.push([t,i,d,n]))}}function v(e){if(!e)return"";for(var t=j("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),i="",d=0;d<e.length;d++){i+=t.indexOf(e[d])>-1?j("XA==")+e[d]:e[d]}return i}function z(e){if(!e)return"";var t="";return e.id&&e.id.length>0&&(t+="#"+v(e.id)),e.className&&e.className.length>0&&(t+="."+v(e.className).split(" ").filter(function(e){return e&&e.length>0}).join(".")),t}function V(e){_e[e]=!1}function m(t,i){var d=Ce++;e.djwioClni&&e.djwioClni.push(d),_e[d]=!0;var n=function(e){return function(){t.call(null),_e[d]&&p(n,e)}}(i);return p(n,i),d}function g(e){var t=!1;return Object.keys(e).forEach(function(i){t=t||e[i]}),!t}function T(e,t){return e&&(e.consents&&e.consents[t]||e.legitimateInterests&&e.legitimateInterests[t])}function F(t){return!!e.djwiobddFlags.strictNCNA&&(T(t,2)&&T(t,7)&&T(t,9)&&T(t,10))}function E(t){return e[j("ZW5jb2RlVVJJQ29tcG9uZW50")](t)}function N(e,t,i){var d=function(){return!!t()&&(i(),!0)};if(!d()){var n=m(function(){d()&&V(n)},250);d()}}function W(e){k(e)}function k(e){if(e.djwio23asdl&&!e.djwiobf6Injct){e.djwiobf6Injct=!0,e.djwio3fePc={},e.djwiofefOc=[],e.djwioee9Am={},e.djwio7aeAv={},e.djwio7a8Aw={},e.djwio792Rqr={},e.djwiocbeRqq=[],e.djwio7aeAvt={},e.djwio94eEv={};var i=[];if(!e.djwiobddFlags.welect.eenabled||ORJSPWelect()){if(djwiobddFlags.ptf65ls){var d=djwiobddFlags.bade2it,n=djwiobddFlags.mb2d2el||10,o=djwiobddFlags.igd6bBP,r=function(){var e=de("style");e.type="text/css";var i=!1,d=de("style");d.type="text/css";var n=!1;return function(r,l){if(l)if("b"!==r||i){if("r"===r)if(n){var p=d,f=p.sheet;f.insertRule(l,0)}else n=!0,ne(d,l),oe(t.body,d)}else{if(i=!0,o)for(var a=0;a<o.length;a++)l=l.replace(new RegExp("([;{])"+o[a]+": [^;]+;","g"),"$1");var p="[^:;{",f="!important;";l=l.replace(new RegExp(p+"}]+: [^;]+\\s"+ ...
# ;ne(o,""+j(Xe(j("..."),-3))),ge(o.childNodes,function(t,d){ce(i,d),e.djwioCln.push(d)}),e.djwioCln.push(i)}function c(t){var i=de("div");n[""+j(Xe(j("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94WzRRdmU2VX0="),-3))]=i,n[""+j(Xe(j("UkdufVJEQEA="),-3))]=i,d[""+j(Xe(j("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94WzRRdmU2VX0="),-3))]=i,ce(t,i),e.djwiod3464.w[8938]=i;var o=de("div");ne(o,""+j(Xe(j("..."),-3))),ge(o.childNodes,function(t,d){ce(i,d),e.djwioCln.push(d)}),M([{function:function(e,t){e.remove&&e.remove()}}],i,8938),e.djwioCln.push(i)}function w(t){var i=de("div");n[""+j(Xe(j("WTVJdmVLRWtmSll8WzRnVlRZRVRVWUxA"),-3))]=i,n[""+j(Xe(j("UkdcOFF6QEA="),-3))]=i,d[""+j(Xe(j("WTVJdmVLRWtmSll8WzRnVlRZRVRVWUxA"),-3))]=i,be(i,"uUMMgbCGJ"),xe(i,"OieOgGtWR "),ce(t,i),e.djwiod3464.w[8697]=i,e.djwioCln.push(i)}function R(t){if(e.djwiocdfMobile&&(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1)){var i=n[""+j(Xe(j("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbfUhA"),-3))];i&&t(i)}}function x(t){var i=de("div");n[""+j(Xe(j("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0O3s="),-3))]=i,n[""+j(Xe(j("UFdQN1JHSEA="),-3))]=i,d[""+j(Xe(j("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0O3s="),-3))]=i,be(i,"ptncUEx"),xe(i,"rkWVmx "),oe(t,i),e.djwiod3464.w[13881]=i;var o=de("div");ne(o,""+j(Xe(j("U0pVc2dsRXNdRzNsZjVdeVxtSGxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1MbFNsRDtPNVVzZ203alNKVXNnbEVzXUczbGY1XXlcbVBsU2xEO081VXNnbTdqU0pVc2dsRXNdRzNsZjVdeVxtVGxTbEQ7TzVVc2dtN0A="),-3))),ge(o.childNodes,function(t,d){ce(i,d),e.djwioCln.push(d)}),e.djwioCln.push(i)}function b(t){if(e.djwiod346tc.pm&&e.djwiocdfMobile&&(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1)){var i=n[""+j(Xe(j("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbNEVR"),-3))];i&&t(i)}}function U(t){var i=de("div");n[""+j(Xe(j("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0PFRXVEBA"),-3))]=i,n[""+j(Xe(j("UFdQN1JXUEA="),-3))]=i,d[""+j(Xe(j("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0PFRXVEBA"),-3))]=i,be(i,"ZSwRAWG"),xe(i,"ytfYypSrhQ "),oe(t,i),e.djwiod3464.w[13893]=i;var o=de("div");ne(o,""+j(Xe(j("U0pVc2dsRXNdRzNsZjVdaWRKemxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1IbFNsRDtPNVVzZ203alNKVXNnbEVzXUczbGY1XXlcbUxsU2xEO081VXNnbTdqU0pVc2dsRXNdRzNsZjVdeVxtUGxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1UbFNsRDtPNVVzZ203QA=="),-3))),ge(o.childNodes,function(t,d){ce(i,d),e.djwioCln.push(d)}),e.djwioCln.push(i)}N(13884,function(){var e=!0,t=i(""+j(Xe(j("T248WVlITVZUWG9SWjVVa2dKSHdnNW9uXTVZM09ab25TVk1FWG87e0xvM2pPcDxsT1pRa2ZwVX0="),-3)),"");return e=e&&t},function(){o(r)}),N(13892,function(){var e=!0,t=i(""+j(Xe(j("T248WVlITVZUWG9SWjVVa2dKSHdnNW9uXTVZM09ab25TVk1FWG87e0xvM0A="),-3)),"");return e=e&&t},function(){l(p)}),function(t){if(e.djwiobddFlags.video){var d=i(""+j(Xe(j("TDVreWVaWHdmcFltZ0pJeF01e29PW1F6ZTZVdmRaZ3JnRkR2TEY4Nl1bTWxnWjhxT1tNb1w2VWtlcGd2XVdIQA=="),-3)),"");d&&t(d)}}(f),function(t){if(e.djwiobddFlags.video){var d=i(""+j(Xe(j("ZVpJc2VsRC5MRjh8ZTZmalNsRHhlSkl8XTVYd1JGRHhlcFk2Znw0NmRaVXFdW1R3T1pReWVxVWtkWjhvZmxEdUxGcnZMSjRrZFo3alNsRHhmcDw2TEc3ak9we2tmcGdvT1dqak9xXXNdW2d6ZTZNM09bVXxcWlF1ZFo4cUxGdmpOakBA"),-3)),"");d&&t(d)}}(a),function(t){if(!(e.djwiocdfMobile||e.djwiobddFlags.ncna&&e.djwiocdfMobile)){var d=i(""+j(Xe(j("T3Fnb2ZwTTRlcGZ3ZjV3OGY1UXxcW0VvZmw0bWU1ODNcWm94XVtMQA=="),-3)),"");d&&t(d)}}(u),N(13886,function(){var e=!0,t=i(""+j(Xe(j("TDZRcFs1a3Y="),-3)),"");return e=e&&t},function(){s(h)}),function(t){if(!(e.djwiocdfMobile||e.djwiobddFlags.ncna&&e.djwiocdfMobile)){var d=i(""+j(Xe(j("TDZNb1w1PHdlWll4XUpZfA=="),-3)),"");d&&t(d)}}(c),function(d){if(!e.djwiocdfMobile&&938<=(e.innerWidth||t.documentElement.clientWidth||t.body.clientWidth)&&(!e.djwiobddFlags.ncna||!e.djwiocdfMobile&&938<=(e.innerWidth||t.documentElement.clientWidth||t.body.clientWidth))){var n=i(""+j(Xe(j("TDU4a2dwb2xcWnt1XVo3dkw1NGtkWjdA"),-3)),"");n&&d(n)}}(w),N(13881,function(){var e=!0,t=n[""+j(Xe(j("V1o8bGRae29bNFFRVFlNWFVuW ...
# e.djwioCln.push(n)}function o(e,t){var d=i[""+j(Xe(j("V1lNaVk2TWtmS0VvZmpAQA=="),-3))];d?e(d):t(12352)}function r(d){var n=de("div");i[""+j(Xe(j("VzZZM2Y2VXxdWkl3WzM0Vg=="),-3))]=n,i[""+j(Xe(j("UFdMfVFXTEA="),-3))]=n,t[""+j(Xe(j("VzZZM2Y2VXxdWkl3WzM0Vg=="),-3))]=n;var o;be(n,"WyXhTBFv"),o="#WyXhTBFv",oe(d,n),e.djwiod3464.a[12352]=n;var r=[];(e.djwiod346tc.gn||e.djwiod346tc.ab)&&r.push(j("QURCTE9DSw==")),e.djwiod346tc.pm&&r.push("PM"),e.djwiobddFlags.nc&&r.push("NC"),0===r.length&&r.push("NONE"),e.postMessage({from:it,to:dt,message:{type:"loadVideoTag",value:{positionId:12352,cssSelector:o,currentTrafficTypes:r}}}),M([{function:function(e,t){m(function(){e.classList.add("nolbl");var t=e.innerText.toLowerCase();t.indexOf("anzeige")>-1||t.indexOf("advertisement")>-1?e.classList.add("nolbl"):ue(e).height>=100&&e.classList.remove("nolbl")},500)}}],n,12352),e.djwioCln.push(n)}N(12353,function(){var t=!0,d=i[""+j(Xe(j("VzZZM2Y2VXxdWkl3WzNdV1s0Z3xcW0V6XVtMQA=="),-3))];return t=t&&d,t=t&&t.getBoundingClientRect().top-e.innerHeight<=-150},function(){d(n,P)}),N(12352,function(){var t=!0,d=i[""+j(Xe(j("V1lNaVk2TWtmS0VvZmpAQA=="),-3))];return t=t&&d,t=t&&t.getBoundingClientRect().top-e.innerHeight<=-150},function(){o(r,P)})}function q(d,n){function o(t,i,n,o){n||ze(Xe("22zzz1wudqvihupdunw1frp2lpdjh2j[QvJUhE[WmWJ7Q5wQK[Y\\Qj4sv5IPk6WYur:3pNhK9f2"+e.djwio94bRnd+"KV]UimRQT|Kxtmiin|lGoxV{\\8\\PyvQ5LeLUvnr5|8gxie;1jli",-3),function(){if(!n){n=!0;var p=this;if(p.height<2)return void P(8694,i,!1);if(o==e.djwio94bRnd){var a=t,u=de("div");d[""+j(Xe(j("VG5vUFdEQEA="),-3))]=u,xe(u,"ZydwkV ");var s=p;e.djwioee9Am[8694]&&(Y(e.djwioee9Am[8694]),e.djwioee9Am[8694]=!1),l(s,function(t,i){if(!e.djwio3fePc[8694]){t.preventDefault(),t.stopPropagation();for(var i=r(t,this),d=0;d<e.djwiofefOc.length;d++){var n=e.djwiofefOc[d];if(8694==n.p&&i.x>=n.x&&i.x<n.x+n.w&&i.y>=n.y&&i.y<n.y+n.h){if(n.u){var o=n.t.length>0?n.t:"_self";o=0==t.button&&t.ctrlKey?"_blank":o,Fe(e,n.u,n.u,o,!0)}return}}var l=[Xe("22zzz1wudqvihupdunw1frp2lpdjh2Gg<g66sW8[rVRXQHy}iPQfR[m\\qQYoWtZLRjjpx|66hG2"+e.djwio94bRnd+"ZYUgoVHtnrPw6\\eVeyX3<oO[ru|5F;|mZRrsplty<LRExMx1jli",-3),Xe("22zzz1wudqvihupdunw1frp2lpdjh2mUv5G;Wrs8JhpRkKLn7wyKE|oOh\\TWWWkql[xLhfMNsQ2"+e.djwio94bRnd+"QGT93OR5eg4{PTl[VH]pFtUeF;iVZEiOF633{hgZWj:jr931jli",-3),Xe("22zzz1wudqvihupdunw1frp2lpdjh2MkvVgWskUpj354Uw7{9RFiftx:Z9L57P5}GNrIPs37[G2"+e.djwio94bRnd+"F\\XiZvX4mlW5{tZiZMIJKx8gKNeS[ekOeU<5GHIiq94sxOG1jli",-3),Xe("22zzz1wudqvihupdunw1frp2lpdjh
V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzt6UGwzelFEQEA="),-3))]=u,xe(u,"lxVwkSiJ ");var s=p;e.djwioee9Am[13880]&&(Y(e.djwioee9Am[13880]),e.djwioee9Am[13880]=!1),l(s,function(t,i){if(!e.djwio3fePc[13880]){t.preventDefault(),t.stopPropagation();for(var i=r(t,this),d=0;d<e.djwiofefOc.length;d++){var n=e.djwiofefOc[d];if(13880==n.p&&i.x>=n.x&&i.x<n.x+n.w&&i.y>=n.y&&i.y<n.y+n.h){if(n.u){var o=n.t.length>0?n.t:"_self";o=0==t.button&&t.ctrlKey?"_blank":o,Fe(e,n.u,n.u,o,!0)}return}}var l=[Xe("22zzz1wudqvihupdunw1frp2lpdjh2GzQGwhGfi6ysEGu]\\ukQTk}F3qfEhEm7nLOtOeUKMvEI2"+e.djwio94bRnd+"LZY:\\llhL6yiX\\o;FR;rYkNiKK]TQNQgfSmii]sVskZgNQF1jli",-3),Xe("22zzz1wudqvihupdunw1frp2lpdjh2sn6LxT<6wtr6NOmrqQ3Kv\\k6[zZ{;uz9TElWuK:xs|:q2"+e.djwio94bRnd+"Q[HfTe:E\\J|5m3kXz|H3js<zj4gqrUG<kPF}QfXfXt|fNG]1jli",-3),Xe("22zzz1wudqvihupdunw1frp2lpdjh2RIhofEhq7[LPluu949h;zwuHy;Kn]5[7HzVVNe{nfPf\\2"+e.djwio94bRnd+"]T\\L<Jl:FFZ<yRnvEII5W[ZNNkI8RXnIIMVkMs9MjrOt7fX1jli",-3),Xe("22zzz1wudqvihupdunw1frp2lpdjh2JFruls97KnvZL6|lU\\qokxSjzR{\\uH:r\\l6lw]OgvpiQ2"+e.djwio94bRnd+"GFHxt<:\\vSXGIQtjlF|h|i4[Ykxfege8pW}|E]s7}{9vQZ:1jli",-3),Xe("22zzz1wudqvihupdunw1frp2lpdjh2{nuOVok;z|no89h ...
# selectorAll:"[id*=div-gpt-ad]",cssApply:{display:"none"}}],u,8695),Ye(u,8695,Xe("22zzz1wudqvihupdunw1frp2lpdjh2RpLp}oVln[685iMIFgO{|N:OFKe{l;KyzthxIgF[im{F2"+e.djwio94bRnd+"XUTws;eW9lww[UG|MXiLQOQhjz]4P5Fo7kIvmu3UnIyOy:I1jli",-3),function(){}),P(8695,i,!0)}}},function(){P(8695,i,!1)})}function K(t,i,d){var o=n[""+j(Xe(j("WDN3XVs0TXNdNWszWzRnfFxbRXpdW0xA"),-3))];o?i(o,!t,!1,e.djwio94bRnd):d(8705,!t,!1)}function I(t,i,n,o){n||ze(Xe("22zzz1wudqvihupdunw1frp2lpdjh2wxQoE4:[EN4kHHf7UyLI6nX|YT9lWKL;e8nLNKWt5;s42"+e.djwio94bRnd+"QEQL}gl8[QpqXQLk}[mrY[i4UvL3]ijILyO4gp]nuExIzk31jli",-3),function(){if(!n){n=!0;var p=this;if(p.height<2)return void P(8705,i,!1);if(o==e.djwio94bRnd){var a=t,u=de("div");d[""+j(Xe(j("WDN3XVs0TXNdNWszWzNda2VKe2xcWlF1"),-3))]=u,xe(u,"CmScjqqhuM ");var s=p;e.djwioee9Am[8705]&&(Y(e.djwioee9Am[8705]),e.djwioee9Am[8705]=!1),l(s,function(t,i){if(!e.djwio3fePc[8705]){t.preventDefault(),t.stopPropagation();for(var i=r(t,this),d=0;d<e.djwiofefOc.length;d++){var n=e.djwiofefOc[d];if(8705==n.p&&i.x>=n.x&&i.x<n.x+n.w&&
ectorAll:"[id*=div-gpt-ad]",cssApply:{display:"none"}}],u,8705),Ye(u,8705,Xe("22zzz1wudqvihupdunw1frp2lpdjh2I58<UjPZYMlF6w4q;JqtQnVHGQ4[VxvinV3ju3jnxoPU2"+e.djwio94bRnd+"]IIVwOOl8uvQ:tGpJYJv5;y9nxvrLtmS7MQZ:yk9lhJGRe91jli",-3),function(){}),P(8705,i,!0)}}},function(){P(8705,i,!1)})}function L(t,d,n){var o=i(""+j(Xe(j("TDZRcGdKTHs="),-3)),"");o?d(o,!t,!1,e.djwio94bRnd):n(8939,!t,!1)}function B(t,i,n,o){n||ze(Xe("22zzz1wudqvihupdunw1frp2lpdjh2qqVO9RN]Zrr]q:uGYnL|NmtsF|4FifS6k9MX7e\\UHQHm2"+e.djwio94bRnd+"MK\\P:4wR3kFQRkQJ{4QXNVj|lRvGFG:M<QRIZHtRiqltn<|1jli",-3),function(){if(!n){n=!0;var p=this;if(p.height<2)ret ...
# e.djwiosc.crt?me(Xe("22zzz1wudqvihupdunw1frp2lpdjh2SH[O[flns\\JWnPTo:uU}qjRQyKqhYNJ[otZloSOphkqJ2"+e.djwio94bRnd+"ZNN<x]k}Q\\Msmgg\\NIg;<jiyI4YoXP6|:7u}NTiNGyusQT81jli",-3),d,d):me(Xe("22zzz1wudqvihupdunw1frp2lpdjh2Vos<LwmLuXVS9m<qwh{FE;9hi<9rK\\:szLpuyFiRhZvM2"+e.djwio94bRnd+"HMEmQZU;NzuRQPwTSQ:gyI]LiUZ{N6yEyXeF[LvS4:ToO\\61jli",-3),d,d)};n(u)}else e.djwiobddFlags.aa&&e.djwiobddFlags.aa.done&&e.djwiobddFlags.aa.enabled?me(Xe("22zzz1wudqvihupdunw1frp2lpdjh2SH[O[flns\\JWnPTo:uU}qjRQyKqhYNJ[otZloSOphkqJ2"+e.djwio94bRnd+"ZNN<x]k}Q\\Msmgg\\NIg;<jiyI4YoXP6|:7u}NTiNGyusQT81jli",-3),d,d):me(Xe("22zzz1wudqvihupdunw1frp2lpdjh2Vos<LwmLuXVS9m<qwh{FE;9hi<9rK\\:szLpuyFiRhZvM2"+e.djwio94bRnd+"HMEmQZU;NzuRQPwTSQ:gyI]LiUZ{N6yEyXeF[LvS4:ToO\\61jli",-3),d,d)}else if(o){if(e.djwiobddFlags.ncrld&&!e.djwiobddFlags.glblrld&&"function"==typeof $){e.djwiobddFlags.glblrld=!0;var r=m(function(){V(r),$()},6e4)}me(Xe("22zzz1wudqvihupdunw1frp2lpdjh2wqE58Gvx{vzynRkmWkSSxnJG]5ee86]RIe9hIV<ZQ<4{2"+e.djwio94bRnd+"NOP75]mGHxYUpgufNqzqMHwR:HqSXXEe}Orl4J:uK6oT{xw1jli",-3),d,d),e.djwiobddFlags.ncna=!0}else et=!1}()}else et=!1},o=!1;if(e.djwiobddFlags.fnc)o=!0,n();else if(e.djwiobddFlags.tcf){var r=e.djwiobddFlags.tcf;o=g(r.purpose.consents)&&!F(r.purpose)&&("tcloaded"==r.eventStatus||"useractioncomplete"==r.eventStatus),n()}else try{var l=function(t,i){try{o=g(t.purpose.consents)&&!F(t.purpose)&&("tcloaded"==t.eventStatus||"useractioncomplete"==t.eventStatus),e.djwiobddFlags.tcf=t}catch(e){o=!1}n()};"undefined"!=typeof __tcfapi?__tcfapi("addEventListener",2,l):n()}catch(e){n()}}function I(t){var i=function(){};"1"==t&&ze(Xe("22zzz1wudqvihupdunw1frp2lpdjh2jl7LM{J{vRir;ewhQR<lFY7n\\N}Ehk{UUykWSIj[S9wV2"+e.djwio94bRnd+"TMLXHR4{gn\\E6eMJqFZtZOTsUL{MXUkju6kFyF|L;PEurh|1jli",-3),i,i),"2"==t&&ze(Xe("22zzz1wudqvihupdunw1frp2lpdjh2ppj:IyHknzzPs7\\w\\PL:h8;o3{tmfwiqNmFmOJrU7g\\i2"+e.djwio94bRnd+"UNOq[LzoiHJOrT|r:7EL{<Xg|wH}eKSq9XpR\\k;UN;trMkQ1jli",-3),i,i),"3"==t&&ze(Xe("22zzz1wudqvihupdunw1frp2lpdjh2Xph\\SHwMxTy6S[9jIF44z\\r{Nwf[RpH\\lkuNxE<oSPhE2"+e.djwio94bRnd+"ITSIgF\\3VmezG4zqlKl{jUQu|KeeU8PR5ZRMs4T9gEomkQF1jli",-3),i,i),"4"==t&&ze(Xe("22zzz1wudqvihupdunw1frp2lpdjh2nhiU{:9\\PYmZpuvX}VXYLx:Y3KEX4J8yzHoenrg5GOPN2"+e.djwio94bRnd+"SMYsxXFXQZiG<Q7<hmH9ms{X{w4Gp8;Kzn;SkWwWL{[J7Nr1jli",-3),i,i)}function L(){e.djwiod346d3++,e.djwiod346d3==e.djwiod3461.length&&e.djwiod3462.length==e.djwiod346d3&&(e.djwiod346tc.ab=!0),e.djwiod346d3==e.djwiod3461.length&&(e.djwiod346tc.abd=!0),J()}function B(){return document.cookie.replace(/(?:(?:^|.*;\s*)xdefccpm\s*\=\s*([^;]*).*$)|^.*$/,"$1")}function J(){var t="";if(!e.djwiobddFlags.nopmcache)try{t=B()}catch(e){}e.djwiobddFlags.pmcache=!0,""!=t&&(e.djwiod346tc.pmd=!0,"yes"===t&&(e.djwiod346tc.pm=!0),e.djwiobddFlags.pmcache=!1),e.djwiobddFlags.pmasync&&(e.djwiod346tc.gn||e.djwiod346tc.ab)&&K(e.djwiod346tc.pm,e.djwiod346tc.gn||e.djwiod346tc.ab),e.djwiod346tc.abd&&e.djwiod346tc.pmd&&e.djwiod346tc.gnd&&K(e.djwiod346tc.pm,e.djwiod346tc.gn||e.djwiod346tc.ab)}function D(){A()}function A(){if(!e.djwio60dDetect){e.djwio60dDetect=!0,e.djwiod346tc.ab=!1,e.djwiod346tc.abd=!1,e.djwiod346tc.gn=!1,e.djwiod346tc.gnd=!1;var t=b();e.djwiocdfMobile=t.match(/iPad/i)||t.match(/iPhone/i)||t.match(/iPod/i)||t.match(/Android/i),e.djwiod3461=[],e.djwiod346o1=[],e.djwiod346o1a=[],e.djwiod346o2=[],e.djwiod346o3=[],e.djwiod346o3a=[],e.djwiod3462=[],e.djwiod346d3=0;try{0!=e.djwiod346d3&&(e.djwiod346d3=0)}catch(e){return void I(4)}e.djwiod3464={},e.djwiod3464.a={},e.djwiod3464.w={},e.djwiod3464.f={},e.djwiod3464.cb=!1,e.djwiod3464.r={},e.djwiod3465={},e.djwiod3465.e=0,e.djwiod3465.s=0,e.djwioe5cij=!1,e.djwiobddFlags.pd4=djwiod3464;var i=(new Date).getTime(),d=function(){if(ye(this))"function"==typeof ORJSPTrkFailed&&ORJSPTrkFailed(Xe("22zzz1wudqvihupdunw1frp2lpdjh2\\RGO{qOL\\orhR8GX}Ex9juFZOEnW[kfYFzE|8ixi{7|w2"+e.djwio94bRnd+"UVE|ZrnrShqljMJ8H3R3Nr9H3}J{Ew[kuINklTL}ZF8X7xv1jli",-3),(new Date).getTime()-i);else if(e.djwiobddFlags.bl18fUp&&Ge(this)){var t=new XMLHttpRequ ...
# ;case"script":g=c.createElement("script"),Array.from(o.attributes).forEach(function(e){re(g,e.nodeName,"src"===e.nodeName?m:e.nodeValue)}),g.onload=function(){He(o,"load")},U(g,"error",n),T=o.parentNode,T&&o.isConnected||(T=c.head),oe(T,g),g.src=a,g.adf_actual_src=m,g.adf_rewritten=!0;break;case"iframe":/imasdk.googleapis.com/.test(a)&&(m+="&="+i(a,!0)),o.contentWindow.location.replace(m);break;case"video":if(o.src!==a)return;U(o,"canplay",function(){fe(o,"display","block","important"),b=!0,o.adf_rewritten=!1,o.play()}),o.preload="auto",o.src=m;break;case"css":o.href=m}},0)}}else if("iframe"===u&&"load"===s&&o.contentDocument){$(o);var w=l("hiddenElement",!1);w&&o.closest(w)||k(200,15,o,u)}}}}}}function _(e){var t=e.target;!t.adf_rewritten&&d(t.src)&&q(t,"iframe",t.src)&&(e.stopImmediatePropagation(),t.removeEventListener("load",_,!0),U(t,"error",C,!0),He(t,"error"))}function $(e){d(e.src)?U(e,"load",_,!0):e.contentDocument?(ae(e.contentDocument),U(e,"load",ee,!0)):p(function(){e.contentDocument?ae(e.contentDocument):U(e,"load",ee,!0)},0)}function ee(e){try{var t=e.target;t.removeEventListener("load",ee,!0),d(t.src)?_(e):t.contentDocument&&(S(t.contentDocument),ae(t.contentDocument))}catch(e){}}function ae(t){if(!t.adf_rewritten){t.adf_rewritten="main";var i=e;i!==t.defaultView&&(t.adf_rewritten="iframe",i=t.defaultView),u(t,"hiddenElement",function(e){k(200,15,e)}),u(t,"anchor",function(e){w(e)}),t.querySelectorAll("script").forEach(function(e){S(e)});var d=e.Function.bind,o=d.bind(d),r=function(e,t){return new(o(e,null).apply(null,t))};i.Image=function(e){function i(){var i=r(e,arguments);return D()?(i.orgnl_script=t.currentScript,S(i),i):i}return i.prototype=e.prototype,i}(i.Image),function(e){i.XMLHttpRequest.prototype.open=function(){var t=this;try{if(!arguments[0]||!arguments[1]||/^\/[^\/]/.test(arguments[1])||!q(t,"xhr",arguments[1])||t.adf_rewritten||t[Pe])return;t.adf_xhrOpenArgs=arguments,t.adf_tagName="xhr",t.adf_req_headers=[]}finally{e.apply(t,arguments)}}}(i.XMLHttpRequest.prototype.open),function(e){i.XMLHttpRequest.prototype.setRequestHeader=function(){var t=this;try{if("xhr"!==t.adf_tagName||t.adf_rewritten||t[Pe]||!(t.adf_req_headers instanceof i.Array)||!D())return;t.adf_req_headers.push(arguments)}finally{e.apply(t,arguments)}}}(i.XMLHttpRequest.prototype.setRequestHeader),function(e){i.XMLHttpRequest.prototype.send=function(){var t=this;try{if("xhr"!==t.adf_tagName||t.adf_rewritten||t[Pe]||t.hasOwnProperty("adf_body")||!D())return;if(t.orgnl_error_hdlr=t.onerror,t.onerror=null,t.orgnl_readystatechange_hdlr=t.onreadystatechange,t.onreadystatechange=function(e){return 4!==t.readyState?void("function"==typeof t.orgnl_readystatechange_hdlr&&t.orgnl_readystatechange_hdlr(e)):/^[23]/.test(t.status)?(e.adf_event_type="load",C(e),void("function"==typeof t.orgnl_readystatechange_hdlr&&t.orgnl_readystatechange_hdlr(e))):(e.adf_event_type="error",void C(e))},t.adf_body=arguments[0],Q({type:"xhr",requestMethod:t.adf_xhrOpenArgs[0],url:t.adf_xhrOpenArgs[1]},"network"))return void A(null,t);S(t)}catch(e){P(t)}finally{e.apply(t,arguments)}}}(i.XMLHttpRequest.prototype.send),function(e){i.open=function(){function t(){if(d&&!d.opener||a>100){try{d.opener=i}catch(e){}V(f)}else a+=1}var d;try{if(!D()||!$e)return void(d=e.apply(i,arguments));var o=arguments[0],r=n(),l=p(function(){B({name:"clickRecovery",timing:3e3})},3e3);U(i,"message",function(e){e.data.message&&"ping"===e.data.message&&e.data.tabId&&e.data.tabId===r&&(clearTimeout(l),e.source.postMessage({message:"pong",targetURL:o,tabId:r,video:!0},"*"))},!0),d=e.apply(i,[Ue+"#"+r]);var f,a=0;try{d.opener=i}catch(e){}f=m(t,1)}catch(t){d=e.apply(i,arguments)}finally{return d}}}(i.open),function(t){e.djwiobddFlags&&e.djwiobddFlags.fetchRecoveryOff||(i.fetch=function(){var e=arguments;try{var d={type:"xhr",requestMethod:e&&e[1]&&e[1].method?e[1].method:"GET",url:e&&e[0]?e[0]:""};return D()&&d.url&&!X(d,"network")?(d.url=R(d.url),v(d.url)?new Promise(function(d,n){t.apply(i,e ...
# </script>
# <div class="werbung werbung-header">
# <script type="text/javascript">
#                 var PWT={}; //Initialize Namespace
#                 var googletag = googletag || {};
#                 googletag.cmd = googletag.cmd || [];
#                 var gptRan = false;
#                 PWT.jsLoaded = function(){ //PubMatic pwt.js on load callback is used to load GPT
#                     loadGPT();
#                 };
#                 var loadGPT = function() {
#                     // Check the gptRan flag
#                     if (!gptRan) {
#                         gptRan = true;
#                         var gads = document.createElement('script');
#                         var useSSL = 'https:' == document.location.protocol;
#                         gads.src = (useSSL ? 'https:' : 'http:') + '//securepubads.g.doubleclick.net/tag/js/gpt.js';
#                         var node = document.getElementsByTagName('script')[0];
#                         node.parentNode.insertBefore(gads, node);
#                     }
#                 };
#                 // Failsafe to call gpt
#                 setTimeout(loadGPT, 500);
#             </script>
# <script type="text/javascript">
#                 (function() {
#                     var purl = window.location.href;
#                     var url = '//ads.pubmatic.com/AdServer/js/pwt/163229/10103';
#                     var profileVersionId = '';
#                     if(purl.indexOf('pwtv=')>0){
#                         var regexp = /pwtv=(.*?)(&|$)/g;
#                     var matches = regexp.exec(purl);
#                     if(matches.length >= 2 && matches[1].length > 0){
#                         profileVersionId = '/'+matches[1];
#                     }
#                 }
#                     var wtads = document.createElement('script');
#                     wtads.async = true;
#                     wtads.type = 'text/javascript';
#                     wtads.src = url+profileVersionId+'/pwt.js';
#                     var node = document.getElementsByTagName('script')[0];
#                     node.parentNode.insertBefore(wtads, node);
#                 })();
#             </script>
# <!-- Start GPT Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#                   window.googletag = window.googletag || {cmd: []};
#                   googletag.cmd.push(function() {
#                     googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600], [120, 600]], "div-gpt-ad-1621527521939-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600], [120, 600]], "div-gpt-ad-1621528123398-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90], [300, 250]], "div-gpt-ad-1621528173524-0")
#                     .addService(googletag.pubads());
#                      googletag.pubads().enableLazyLoad({
#                         fetchMarginPercent: 500,
#                         renderMarginPercent: 200,
#                         mobileScaling: 2.0});
#                     googletag.pubads().setCentering(true);
#                     googletag.pubads().disableInitialLoad();
#                     googletag.pubads().enableSingleRequest();
#                     googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                     googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                     googletag.enableServices();
#                   });
#                 </script>
# <!-- End GPT Tag -->
# </div> <script>
#         ! function(e, n) {
#             function t(e) {
#                 return "object" == typeof e ? JSON.parse(JSON.stringify(e)) : e
#             }
#             e[n] = e[n] || {
#                 nlsQ: function(o, r, c) {
#                     var s = e.document,
#                         a = s.createElement("script");
#                     a.async = 1,
#                         a.src = ("http:" === e.location.protocol ? "http:" : "https:") + "//cdn-gl.nmrodam.com/conf/" + o + ".js#name=" + r + "&ns=" + n;
#                     var i = s.getElementsByTagName("script")[0];
#                     return i.parentNode.insertBefore(a, i),
#                         e[n][r] = e[n][r] || {
#                             g: c || {},
#                             ggPM: function(o, c, s, a, i) {
#                                 e[n][r].q = e[n][r].q || [];
#                                 try {
#                                     var l = t([o, c, s, a, i]);
#                                     e[n][r].q.push(l)
#                                 } catch (e) {
#                                     console && console.log && console.log("Error: Cannot register event in Nielsen SDK queue.")
#                                 }
#                             },
#                             trackEvent: function(o) {
#                                 e[n][r].te = e[n][r].te || [];
#                                 try {
#                                     var c = t(o);
#                                     e[n][r].te.push(c)
#                                 } catch (e) {
#                                     console && console.log && console.log("Error: Cannot register event in Nielsen SDK queue.")
#                                 }
#                             }
#                         },
#                         e[n][r]
#                 }
#             }
#         }(window, "NOLBUNDLE");
#         var nSdkInstance = NOLBUNDLE.nlsQ("PE4A80FAF-20B6-495A-80A9-DF01A093F9EF", "nlsnInstance");
#     </script>
# </link></link></head>
# <body class="" data-cmp-layer-id="225676" data-tm-tld="com" itemscope="" itemtype="http://schema.org/WebPage">
# <div id="main">
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });</script>
# </div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });</script>
# </div> </div>
# <header class="tm-header">
# ...
# <td class="rechts" style="padding-right: 2px;">
# <a href="/vitor-leque/transfers/spieler/752552/transfer_id/4462157?from=neustetransfersbox" title="Vitor Leque">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         End of loan                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Mark Travers" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/357658-1612225044.jpg?lm=1" title="Mark Travers"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/mark-travers/profil/spieler/357658" title="Mark Travers">Mark Travers</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Goalkeeper                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/stoke-city/transfers/verein/512" title="Stoke City"><img alt="Stoke City" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/512.png?lm=1472243727" title="Stoke City"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/mark-travers/transfers/spieler/357658/transfer_id/4536074?from=neustetransfersbox" title="Mark Travers">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/afc-bournemouth/transfers/verein/989" title="AFC Bournemouth"><img alt="AFC Bournemouth" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/989.png?lm=1457991811" title="AFC Bournemouth"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/mark-travers/transfers/spieler/357658/transfer_id/4536074?from=neustetransfersbox" title="Mark Travers">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         End of loan                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Sokratis Papastathopoulos" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/34322-1502448705.jpg?lm=1" title="Sokratis Papastathopoulos"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/sokratis-papastathopoulos/profil/spieler/34322" title="Sokratis Papastathopoulos">S. Papastathopoulos</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/sokratis-papastathopoulos/transfers/spieler/34322/transfer_id/4705128?from=neustetransfersbox" title="Sokratis Papastathopoulos">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/real-betis-sevilla/transfers/verein/150" title="Real Betis Balompié"><img alt="Real Betis Balompié" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/150.png?lm=1663358526" title="Real Betis Balompié"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/sokratis-papastathopoulos/transfers/spieler/34322/transfer_id/4705128?from=neustetransfersbox" title="Sokratis Papastathopoulos">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2024                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Luke Fleurs" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/467606-1617212297.png?lm=1" title="Luke Fleurs"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/luke-fleurs/profil/spieler/467606" title="Luke Fleurs">Luke Fleurs</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/luke-fleurs/transfers/spieler/467606/transfer_id/4704779?from=neustetransfersbox" title="Luke Fleurs">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/kaizer-chiefs/transfers/verein/568" title="Kaizer Chiefs"><img alt="Kaizer Chiefs" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/568.png?lm=1404764408" title="Kaizer Chiefs"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/luke-fleurs/transfers/spieler/467606/transfer_id/4704779?from=neustetransfersbox" title="Luke Fleurs">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2025                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Théo Valls" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/341396-1544005286.jpg?lm=1" title="Théo Valls"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/theo-valls/profil/spieler/341396" title="Théo Valls">Théo Valls</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Central Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/theo-valls/transfers/spieler/341396/transfer_id/4704759?from=neustetransfersbox" title="Théo Valls">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/grenoble-foot-38/transfers/verein/1290" title="Grenoble Foot 38"><img alt="Grenoble Foot 38" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1290.png?lm=1662148312" title="Grenoble Foot 38"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/theo-valls/transfers/spieler/341396/transfer_id/4704759?from=neustetransfersbox" title="Théo Valls">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2026                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="content-link" href="/statistik/letztetransfers">Complete list</a>
# </div>
# <div class="werbung werbung-rectangle2"><div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });</script>
# </div> </div>
# </div>
# <div class="werbung werbung-fullsize_contentad"><div id="div-gpt-ad-1621528173524-0" style="min-width: 728px; min-height: 90px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528173524-0"); });</script>
# </div> </main>
# <footer>
# <div class="tm-footer">
# <a class="tm-footer__logo" href="/">
# <img alt="Transfermarkt" height="33" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" width="80"/>
# </a>
# <ul class="tm-footer__links">
# <li class="tm-footer__links-item">
# <a href="/intern/impressum">
#           Legal notice      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/web/datenschutz">
#           Data protection      </a>
# </li>
# <li class="tm-footer__links-item">
# <a class="cmp-link" href="javascript:void(0)">
#           Privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/anb">
#           General terms of use      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/tmteam">
#           The TM team      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/faq">
#           FAQ      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/fehlermelden">
#           Found a mistake?      </a>
# </li>
# </ul>
# </div>
# </footer>
# <div id="menue_overlay"></div>
# </div>
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "co":""
# }
#     </script>
# <script type="module">
#         var defaultOptions = {
#             tracking: !0,
#             refreshAds: !0
#         };
#         export var refreshAd = function() {
#             var e, n;
#             [ASCDP.hasOwnProperty("adS"), null === (e = ASCDP.adS) || void 0 === e ? void 0 : e.hasOwnProperty("reloadAds"), "function" == typeof(null === (n = ASCDP.adS) || void 0 === n ? void 0 : n.reloadAds)].every(function(e) {
#                 return e
#             }) && ASCDP.adS.reloadAds()
#         };
#         export var TmTrackingAndAds = function(e, n) {
#             void 0 === n && (n = defaultOptions);
#             var r = ["tabelle", "reiter", "forum"].includes(e) ? e : "";
#             n.tracking && (gtag("event", "page_view", {
#                 page_path: "/jsContent" + window.location.pathname
#             }), sendIvwData(r)), n.refreshAds && "undefined" != typeof ASCDP && refreshAd()
#         };
#         window.tmTrackingAndAds = function(e, n) {
#             return TmTrackingAndAds(e, n)
#         };
#     </script>
# <script type="text/javascript">
#             if (typeof IOMm === 'function') {
#                 IOMm('configure', {
#                     st: iam_data.st,
#                     dn: 'data-84a0f3455d.transfermarkt.com',
#                     mh: 5
#                 });
#                 IOMm('pageview', {
#                     cp: iam_data.cp,
#                     co: iam_data.co
#                 });
#             } else {
#                 console.warn('IOMm is not defined');
#             }
#         </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script>
#             $(function() {
#                 var cnt = $('div.large-4.columns').length;
#                 if (cnt == 1) {
#                     var sidebarDiv = document.querySelector('div.large-4.columns');
#                     if (sidebarDiv !== null) {
#                         $('#werbung_recommender_sidebar_wrapper').appendTo(sidebarDiv);
#                         $('#werbung_recommender_sidebar_wrapper').show();
#                     }
#                 }
#             });
#         </script>
# <div id="werbung_recommender_sidebar_wrapper" style="display: none;">
# <div class="box" id="recommender_sidebar">
# <div class="OUTBRAIN" data-widget-id="SL_DT_SB"></div>
# <script async="async" src="//widgets.outbrain.com/outbrain.js" type="text/javascript">
# </script>
# </div>
# </div>
# <script defer="" src="https://tmsi.akamaized.net/js/custom-element-globals/tm-global-elements.esm.js" type="module"></script><script defer="" nomodule="" src="https://tmsi.akamaized.net/js/custom-element-globals/tm-global-elements.js"></script><script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1698743566" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/tm-menu.min.js?lm=1698743565" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/vendors.min.js?lm=1698743565" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var loginUrl='/profil/login';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function sendIvwData(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "co":""
# }
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "co":""
# }
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "co":""
# }
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "co":""
# }
#
#     }
#     if(typeof IOMm === 'function') {
#         IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#     }
# }
# window.articlemetadata = {
#     type: "static",
#     assetid: 'statistik-global',
#     section:  'statistik',
#     segA: iam_data.cp,
#     segB: "CPI",
#     segC: "",
#     subbrand: "c18"
#     };
# nSdkInstance.ggPM("staticstart", window.articlemetadata);
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page','afterAjaxUpdate':function() {window.LazyLoadInstance.update(); tmTrackingAndAds(); document.dispatchEvent(new CustomEvent("tmInitTooltip"));}});
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
# 선수들의 정보가 담긴 태그와 class_ 찾기
player_info = soup.find_all('tr', class_={'odd', 'even'})

# %%
# 첫번째 요소 확인하기
print(player_info[0])

# 전체 개수 확인하기
print("")
print('전체 선수들의 개수: ', len(player_info),'개')
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Erling Haaland" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/418560-1694590614.jpg?lm=1" title="Erling Haaland"/></a></td><td class="hauptlink"><a href="/erling-haaland/profil/spieler/418560" title="Erling Haaland">Erling Haaland</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">23</td><td class="zentriert"><img alt="Norway" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/125.png?lm=1520611569" title="Norway"/></td><td class="zentriert"><a href="/manchester-city/startseite/verein/281" title="Manchester City"><img alt="Manchester City" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/281.png?lm=1467356331" title="Manchester City"/></a></td><td class="rechts hauptlink"><a href="/erling-haaland/marktwertverlauf/spieler/418560">€180.00m</a> </td></tr>
#
# 전체 선수들의 개수:  25 개

# %%
# 가져올 7개의 정보가 담길 빈 리스트 만들기
# number, name, position, age, nation, team, value
number = [] 
name = []
position = []
age = []
nation = []
team = []
value = []

# %%
# player_info에서 'td' 태그만 모두 찾기
for info in player_info:
    player = info.find_all("td")
#     print(player)
#     print(player[0])
    
# 해당정보를 찾아서 각 리스트에 .append로 추가하기
#     number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip()) #strip() 앞뒤 공백 제거

# %% [markdown]
# name

# %%
#pd.DataFrame()으로 저장하기

df = pd.DataFrame(
    {"number": number,
     "name":name,
     "position": position,
     "age": age,
     "nation": nation,
     "team":team,
     "value": value
    })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 #pd.DataFrame()으로 저장하기
# ----> 3 df = pd.DataFrame(
#       4     {"number": number,
#       5      "name":name,
#       6      "position": position,
#       7      "age": age,
#       8      "nation": nation,
#       9      "team":team,
#      10      "value": value
#      11     })
#
# File ~\anaconda\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~\anaconda\Lib\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda\Lib\site-packages\pandas\core\internals\construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~\anaconda\Lib\site-packages\pandas\core\internals\construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length
